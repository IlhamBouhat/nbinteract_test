# %% [markdown]
# # Programming Lesson and Exercises - EDA<span class="tocSkip"></span>
#
# These programming lessons do not require prior programming experience.
#
# The goal is to teach you the use of _Python 3_ and the _Jupyter Notebook_ software
# in the context of _Data Analytics_.

# %% [markdown]
# # Introduction to this template notebook
#
# * This is a **personal** notebook.
# * Make sure you work in a **copy** of `...-template.ipynb`,
# **renamed** to `...-yourIDnr.ipynb`,
# where `yourIDnr` is your TU/e identification number.
#
# <div class="alert alert-danger" role="danger">
# <h3>Integrity</h3>
# <ul>
#     <li>In this course you must act according to the rules of the TU/e code of scientific conduct.</li>
#     <li>All the exercises and the graded assignments are to be executed individually and independently.</li>
#     <li>You must not copy from the Internet, your friends, books... If you represent other people's work as your own, then that constitutes fraud and will be reported to the Examination Committee.</li>
#     <li>Making your work available to others (complicity) also constitutes fraud.</li>
# </ul>
# </div>
#
# You are expected to work with Python code in this notebook.
#
# The locations where you should write your solutions can be recognized by
# **marker lines**,
# which look like this:
#
# >`#//`
# >    `BEGIN_TODO [Label]` `Description` `(n points)`
# >
# >`#//`
# >    `END_TODO [Label]`
#
# <div class="alert alert-warning" role="alert">Do NOT modify or delete these marker lines.  Keep them as they are.<br/>
# <br/>
# NEVER write code <i>outside</i> the marked blocks.
# Such code cannot be evaluated.
# </div>
#
# Proceed in this notebook as follows:
# * **Read** the text.
# * **Fill in** your solutions between `BEGIN_TODO` and `END_TODO` marker lines.
# * **Run** _all_ code cells (also the ones _without_ your code),
#     _in linear order_ from the first code cell.
#
# **Personalize your notebook**:
# 1. Copy the following three lines of code:
#
#   ```python
#   AUTHOR_NAME = 'Your Full Name'
#   AUTHOR_ID_NR = '1234567'
#   AUTHOR_DATE = 'YYYY-MM-DD'  # when notebook was first modified, e.g. '2019-02-26'
#   ```
#
# 1. Paste them between the marker lines in the next code cell.
# 1. Fill in your _full name_, _identification number_, and the current _date_ as strings between quotes.
# 1. Run the code cell by putting the cursor there and typing **Control-Enter**.

# %%
#// BEGIN_TODO [Author] Name, Id.nr., Date, as strings (1 point)

AUTHOR_NAME = 'Kyra Moviat'
AUTHOR_ID_NR = '1349171'
AUTHOR_DATE = '2019-02-07' 

#// END_TODO [Author]

AUTHOR_NAME, AUTHOR_ID_NR, AUTHOR_DATE
# Out:
# ('Kyra Moviat', '1349171', '2019-02-07')

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Learning-Objectives" data-toc-modified-id="Learning-Objectives-1">Learning Objectives</a></span></li><li><span><a href="#Introduction" data-toc-modified-id="Introduction-2">Introduction</a></span><ul class="toc-item"><li><span><a href="#Other-learning-resources-for-Pandas" data-toc-modified-id="Other-learning-resources-for-Pandas-2.1">Other learning resources for Pandas</a></span></li><li><span><a href="#Importing-the-library" data-toc-modified-id="Importing-the-library-2.2">Importing the library</a></span></li><li><span><a href="#1.-Data-frames" data-toc-modified-id="1.-Data-frames-2.3"><span class="section">1.</span> Data frames</a></span></li><li><span><a href="#2.-Index-and-Series-objects" data-toc-modified-id="2.-Index-and-Series-objects-2.4"><span class="section">2.</span> <code>Index</code> and <code>Series</code> objects</a></span></li><li><span><a href="#Error-handling" data-toc-modified-id="Error-handling-2.5">Error handling</a></span></li><li><span><a href="#3.-Getting-data-from-a-DataFrame" data-toc-modified-id="3.-Getting-data-from-a-DataFrame-2.6"><span class="section">3.</span> Getting data from a <code>DataFrame</code></a></span></li><li><span><a href="#4.-Modifying-a-DataFrame" data-toc-modified-id="4.-Modifying-a-DataFrame-2.7"><span class="section" id="section_copy">4.</span> Modifying a <code>DataFrame</code></a></span></li><li><span><a href="#5.-Reading-data-from-a-file-into-a-DataFrame" data-toc-modified-id="5.-Reading-data-from-a-file-into-a-DataFrame-2.8"><span class="section">5.</span> Reading data from a file into a <code>DataFrame</code></a></span></li><li><span><a href="#6.-Summary-statistics" data-toc-modified-id="6.-Summary-statistics-2.9"><span class="section">6.</span> Summary statistics</a></span></li><li><span><a href="#7.-Sorting-a-DataFrame" data-toc-modified-id="7.-Sorting-a-DataFrame-2.10"><span class="section">7.</span> Sorting a <code>DataFrame</code></a></span></li><li><span><a href="#8.-Computing-values-from-a-DataFrame" data-toc-modified-id="8.-Computing-values-from-a-DataFrame-2.11"><span class="section">8.</span> Computing values from a <code>DataFrame</code></a></span></li><li><span><a href="#9.-Selecting-rows-by-boolean-masks" data-toc-modified-id="9.-Selecting-rows-by-boolean-masks-2.12"><span class="section">9.</span> Selecting rows by boolean masks</a></span></li><li><span><a href="#10.-Grouping-rows-in-a-DataFrame" data-toc-modified-id="10.-Grouping-rows-in-a-DataFrame-2.13"><span class="section">10.</span> Grouping rows in a <code>DataFrame</code></a></span></li><li><span><a href="#11.-Deleting-rows-or-columns-from-a-DataFrame" data-toc-modified-id="11.-Deleting-rows-or-columns-from-a-DataFrame-2.14"><span class="section">11.</span> Deleting rows or columns from a <code>DataFrame</code></a></span></li><li><span><a href="#12.-Persisting-the-modifications" data-toc-modified-id="12.-Persisting-the-modifications-2.15"><span class="section">12.</span> Persisting the modifications</a></span></li><li><span><a href="#13.-Plotting-a-DataFrame" data-toc-modified-id="13.-Plotting-a-DataFrame-2.16"><span class="section">13.</span> Plotting a <code>DataFrame</code></a></span></li></ul></li><li><span><a href="#14.-Exercise:-speed-of-light" data-toc-modified-id="14.-Exercise:-speed-of-light-3"><span class="section">14.</span> Exercise: speed of light</a></span></li><li><span><a href="#(End-of-Notebook)" data-toc-modified-id="(End-of-Notebook)-4">(End of Notebook)</a></span></li></ul></div>

# %% [markdown]
# # Learning Objectives
#
# After this section, you should
#
# * Be able to work with Pandas `DataFrame` and `Series` objects;
#     in particular,
#
#     * to create,
#     * to inspect and extract parts from,
#     * to modify,
#     * to compute summary statistics for, and
#     * to visualize
#
#   `DataFrame` objects.

# %% [markdown]
# # Introduction
#
# Most of the programming for Data Analytics will involve
# Python libraries that provide solutions for specific data analysis tasks.
#
# In this section,
# we introduce you to the **Pandas** library.
# The name '_Pandas_' is a contraction of '_Panel Data_',
# which you can think of as tabular data, like a spreadsheet,
# with multiple (labeled) rows and columns.
#
# The Pandas library is automatically installed when _Anaconda_ is installed.

# %% [markdown]
# ## Other learning resources for Pandas
#
# This section cannot and will not cover all details.
# We have selected a small number of key features
# to achieve maximal effect.
#
# Sometimes you may want to consult other information sources:
#
# * `tool-summary*.ipynb`
# * The _Python Data Science Handbook_ by Jake VanderPlas,
#   the chapter [_Data Manipulation with Pandas_](https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/03.00-Introduction-to-Pandas.ipynb)
#   It provides a more comprehensive introduction, and further background information.
#   This book is also available as [ebook in the TU/e library](https://tue.on.worldcat.org/oclc/964358680).
# * The official [Pandas documentation](http://pandas.pydata.org/).
#   The Jupyter Notebook Help menu contains a menu item that leads there.
# * **Code completion** and **built-in** help in code cells,
#   using the **TAB** key and **Shift-TAB-TAB**.
# * Web search; but be warned that older solutions may no longer be valid or the most appropriate.

# %% [markdown]
# ## Importing the library
#
# In order to use facilities from Pandas, you first need to import the Pandas library.
# It is useful to import NumPy as well,
# even though we will not make (much) use of it,
# since Pandas is built on top of NumPy.
#
# The next code cell shows the common way to do these imports,
# introducing the abbreviations `np` for NumPy and `pd` for Pandas.
# Execute this code cell (it will not result in any output).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# When you type an _identifier_ in a code cell, such as `pd`, followed by **Shift-TAB-TAB**,
# you get a floating window with the **built-in documentation** for that identifier:
#
# ![Shift-Tab-Tab.png](attachment:Shift-Tab-Tab.png)
#
# Try it with `pd`:

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %% [markdown]
# Alternatively, you can show the built-in documentation by appending a `?` at the end:

# %%
pd?

# %% [markdown]
# When you type _part of an identifier_,
# followed by **TAB**, an attempt is made at **code completion**.
# When there are multiple possibilities to complete the identifier,
# a pop-up menu with all options is shown:
#
# ![Code-Completion.png](attachment:Code-Completion.png)
#
# You can either
# * continue typing more characters of the identifier,
#     in which case the shown list will become shorter, or
# * you can select a particular item by
#     * clicking it with the mouse pointer, or
#     * moving the selection with the _arrow keys_ and hitting _Enter_.
#
# Try it: starting with `pd.D` hit TAB to complete this to `pd.DataFrame`.
# Next, do Shift-TAB-TAB to get its built-in documentation.

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## <span class="section">1.</span> Data frames
#
# The most important data type of the Pandas library is **`pd.DataFrame`**.
# It is a _composite_ data type, whose values are called **data frames**.
#
# A data frame is a two-dimensional arrangement of data values. It can be helpful to think of it as a table with rows and columns.
# The data itself is typically of a primitive data type (`int`, `float`, `bool`, `str`,
# but also some variants of these as offered by the NumPy library;
# details are not relevant at this point).
#
# Here is an example in which we create a data frame from scratch; we name it `df`.
# It has
#
# * four rows indexed from 0 through 3, and
# * three columns labeled `'A'`, `'B'`, and `'C'`.

# %%
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': ['one', 'two', 'three', 'four'], 'C': [False, True, False, True]})
df
# Out:
#    A      B      C
# 0  1    one  False
# 1  2    two   True
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# The following diagram illustrates some terminology:
#
# <img src="attachment:DataFrame-terminology.png" alt="DataFrame terminology" align="center" width="400px">
#
# * A **row** is a horizontal selection of data values.
# * A **column** is a vertical selection of data values.
# * The **index** provides an identification of the rows.
# * The **column labels** provide an identification of the columns.
#
# Typically, all values in one column have the same type.
# Values in a row can be of different types.

# %% [markdown]
# ### Information about a `DataFrame`
#
# The following attributes provide information about the `DataFrame df`.
#
# * **`df.shape`** : the number of rows and number of columns
# * **`df.index`** : the row index
# * **`df.columns`** : the column labels
# * **`df.dtype`** : the types of the values in each column

# %%
df.shape
# Out:
# (4, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.dtypes
# Out:
# A     int64
# B    object
# C      bool
# dtype: object

# %% [markdown]
# The `DataFrame` function **`info()`** returns
# an overview of a data frame, including its `RangeIndex`, number of `non-null` elements per column, types of the values in each column, and memory usage:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# A    4 non-null int64
# B    4 non-null object
# C    4 non-null bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 148.0+ bytes

# %% [markdown]
# We see that there are 4 rows. There are three columns of data, each containing 4 values of the following types:
#
# * column `'A'` contains 64-bit integers
# * column `'B'` contains generic Python objects
# > NOTE: A column containing `string` values, or values of different types, will  be assigned the `object` type.
# * column `'C'` contains boolean values

# %% [markdown]
# ### Exercise <span class="exercise">1.a</span>

# %% [markdown]
# Suppose we are given the names and years of birth of five persons,

# %%
names = ['Peter', 'Anna', 'Tom', 'John', 'Simone']
years = [ 1998, 2002, 1946, 1973, 1962 ]

# %% [markdown]
# and want to organize this information in a data frame.

# %% [markdown]
# Create a dataframe `df_years` out of this information containing two columns. One column should be labeled `'Name'` and contain the names, and the other should be labeled `'Year of birth'` and contain the year of birth.

# %%
#// BEGIN_TODO [EDA_1a] Create a dataframe (1 point)

df_years = pd.DataFrame({'Name': names, 'Year of birth': years})

#// END_TODO [EDA_1a]
df_years
# Out:
#      Name  Year of birth
# 0   Peter           1998
# 1    Anna           2002
# 2     Tom           1946
# 3    John           1973
# 4  Simone           1962

# %% [markdown]
# ### Exercise <span class="exercise">1.b</span>

# %% [markdown]
# Use the `info()` function to get an overview of the dataframe `df_years`

# %%
#// BEGIN_TODO [EDA_1b] Get an overview of df_years (1 point)

df_years.info()

#// END_TODO [EDA_1b]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
# Name             5 non-null object
# Year of birth    5 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %% [markdown]
# ##  <span class="section">2.</span> `Index` and `Series` objects
#
# To understand Pandas data frames better,
# you should know about two more data types:
#
# * **`pd.Index`**:
#     this is a special type of object that holds the index;
#     by default, it is just a range of integers starting from 0.
# * **`pd.Series`**:
#     this type represents a single named sequence of data values of the same type,
#     with an index.
#     It is used for a single column in a data frame,
#     but also for a row extracted from a data frame,
#     where the column labels then serve as the `Series` index,
#     and the row index serves as the `Series` name.
#
# Thus, a data frame is a sequence of `Series` objects,
# with a shared `Index` object.
# The names of the `Series` objects are the column labels.

# %% [markdown]
# Let us again consider the example with the list of names and years of birth

# %%
names = ['Peter', 'Anna', 'Tom', 'John', 'Simone']
years = [ 1998, 2002, 1946, 1973, 1962 ]

# %% [markdown]
# This time, instead of creating a data frame, we create a `Series` object out of the information as follows. The `Series` object itself will contain the years of birth, it will be indexed by the names, and the object will be called `'Years of birth'`. We assign the object to variable `se_years`:

# %%
se_years = pd.Series( years, index=names, name='Years of birth' )
se_years
# Out:
# Peter     1998
# Anna      2002
# Tom       1946
# John      1973
# Simone    1962
# Name: Years of birth, dtype: int64

# %% [markdown]
# ### Exercise <span class="exercise">2.a</span>

# %% [markdown]
# Create a `pd.Series` object containing the following prices (in Euro)

# %%
prices = [2, 1, 3, 2.5, 1.5 ]

# %% [markdown]
# and indexed by the following items

# %%
items  = ['bread', 'milk', 'chips', 'bananas', 'carrots']

# %% [markdown]
# The series should be named `'Price (Euro)'`. Assign the resulting series to the variable `se_shopping_list`.

# %%
#// BEGIN_TODO [EDA_2a] Create an indexed list (1 point)

se_shopping_list = pd.Series(prices, index=items, name='Price (Euro)')

#// END_TODO [EDA_2a]
se_shopping_list
# Out:
# bread      2.0
# milk       1.0
# chips      3.0
# bananas    2.5
# carrots    1.5
# Name: Price (Euro), dtype: float64

# %% [markdown]
# ## Error handling
#
# In case of errors, it is often useful to inspect the variable types. We can inspect the type of `DataFrame` and `Series` variables using the **`type()`** function:

# %%
type(df) # type of the df variable
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['C']) # type of the 'C' column in the df DataFrame
# Out:
# pandas.core.series.Series

# %%
type(se_years) # type of the se_years variable
# Out:
# pandas.core.series.Series

# %% [markdown]
# Note that a column has the `Series` type, which is not the same as the type of the values inside of a column. You can get the type of the values inside of a column using **`df.dtypes`**:

# %%
df.dtypes['C']
# Out:
# dtype('bool')

# %% [markdown]
# ##  <span class="section">3.</span> Getting data from a `DataFrame`

# %% [markdown]
# You can **get a column** from a data frame by indexing, just like a sequence.
# The result is a `Series` object.
# This is useful to extract a particular feature from the data set.

# %%
df['B']
# Out:
# 0      one
# 1      two
# 2    three
# 3     four
# Name: B, dtype: object

# %% [markdown]
# To **get a row** from a data frame,
# you use the `DataFrame` attribute `loc`.
# It is called an _indexer attribute_,
# because it supports indexing
# with _square brackets_, just like indexing of lists.
# The result is also a `Series` object:

# %%
df.loc[2]
# Out:
# A        3
# B    three
# C    False
# Name: 2, dtype: object

# %% [markdown]
# You can **get a value** at a given location in a data frame
# in several ways:
#
# * **`df[column_label][row_index]`** : first get the column,
#     then get the value from the resulting `Series` object
# * **`df.loc[row_index, column_label]`** : get the value directly,
#     using `loc` with the row index and column label

# %%
df['B'][2]
# Out:
# 'three'

# %%
df.loc[2, 'B']
# Out:
# 'three'

# %% [markdown]
# _Slicing_ can be used to **get larger parts from a data frame**,
# with a syntax similar to the slicing of lists.
#
# > NOTE: When slicing `DataFrame` and `Series` objects
# > with the syntax `.loc[start:stop]`,
# > the **`stop` value is included**.
# > This contrasts to _list_ slicing, where `stop` is _not_ included.
#
# To select a slice of rows,
# use `.loc[start:stop]`.
# The result is a (new!) data frame:

# %%
df.loc[1:2]
# Out:
#    A      B      C
# 1  2    two   True
# 2  3  three  False

# %% [markdown]
# When `start` or `stop` is omitted in the slice `start:stop`,
# the first or last item is implied. Therefore, `.loc[:]` extracts all rows:

# %%
df.loc[:]
# Out:
#    A      B      C
# 0  1    one  False
# 1  2    two   True
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# The `DataFrame` function call **`df.head(n)`** returns the first `n` rows of the data frame `df`,
# regardless of how the rows are indexed.
# The default value for `n` is 5 (i.e. omitting the value in `df.head()` is equivalent to `df.head(5)`).

# %%
df.head(2)
# Out:
#    A    B      C
# 0  1  one  False
# 1  2  two   True

# %% [markdown]
# You can also apply slicing to the columns:

# %%
df.loc[:, 'A':'B']
# Out:
#    A      B
# 0  1    one
# 1  2    two
# 2  3  three
# 3  4   four

# %% [markdown]
# Note that here the first `:` argument tells to select all the rows.
#
# Using `.loc` we can also extract a particular slice of rows and columns in one go:

# %%
df.loc[1:2, 'A':'B']
# Out:
#    A      B
# 1  2    two
# 2  3  three

# %% [markdown]
# To **get _non-adjacent_ rows**,
# use `.loc` with a _list of row indices_
# (note the **double square brackets**).
# The result is a (new!) data frame:

# %%
df.loc[[1, 3]]
# Out:
#    A     B     C
# 1  2   two  True
# 3  4  four  True

# %% [markdown]
# You can also **get _non-adjacent_ columns**.
# One way is by providing a _list of column labels_ directly to the data frame
# (note the **double square brackets**).
# The result is a (new!) data frame:

# %%
df[['A', 'C']]
# Out:
#    A      C
# 0  1  False
# 1  2   True
# 2  3  False
# 3  4   True

# %% [markdown]
# An alternative way of getting non-adjacent columns,
# is to use `.loc` with a _full slice_ for the rows using just '`:`':

# %%
df.loc[:, ['A', 'C']]
# Out:
#    A      C
# 0  1  False
# 1  2   True
# 2  3  False
# 3  4   True

# %% [markdown]
# Note that `df['B']` returns column '`B`' as a `Series` object.
# Sometimes it is more convenient to get it as a `DataFrame` with one column.
# This is achieved by using a list with only one element `'B'` as column label
# (note the **double square brackets**):

# %%
df[['B']]
# Out:
#        B
# 0    one
# 1    two
# 2  three
# 3   four

# %% [markdown]
# ### Exercise <span class="exercise">3.a</span>

# %% [markdown]
# For the purpose of this exercise, we first organize the information

# %%
prices = [2, 1, 3, 2.5, 1.5 ]
items  = ['bread', 'milk', 'chips', 'bananas', 'carrots']

# %% [markdown]
# into a data frame called `df_shopping_list`

# %%
df_shopping_list = pd.DataFrame( { 'Item': items, 'Price (Euro)': prices } )
df_shopping_list
# Out:
#       Item  Price (Euro)
# 0    bread           2.0
# 1     milk           1.0
# 2    chips           3.0
# 3  bananas           2.5
# 4  carrots           1.5

# %% [markdown]
# Create a _new_ data frame containing the first four rows from `df_shopping_list` and assign it to `df_short_list`.

# %%
#// BEGIN_TODO [EDA_3a] Select first rows (1 point)

df_short_list = df_shopping_list.loc[0:3]

#// END_TODO [EDA_3a]

df_short_list
# Out:
#       Item  Price (Euro)
# 0    bread           2.0
# 1     milk           1.0
# 2    chips           3.0
# 3  bananas           2.5

# %% [markdown]
# ### Exercise <span class="exercise">3.b</span>
#
# Use an expression to select the `'Item'` column from the data frame `df_shopping_list` so that the result is a `Series` object.

# %%
#// BEGIN_TODO [EDA_3b] Select a column (1 point)

df_shopping_list['Item']

#// END_TODO [EDA_3b]
# Out:
# 0      bread
# 1       milk
# 2      chips
# 3    bananas
# 4    carrots
# Name: Item, dtype: object

# %% [markdown]
# ### Exercise <span class="exercise">3.c</span>
#
# Use an expression to select the prices from the rows with indices 2 to 4 (including 4), but now make sure the result is a data frame.

# %%
#// BEGIN_TODO [EDA_3c] Select rows _and_ columns (1 point)

df_shopping_list.loc[1:3]

#// END_TODO [EDA_3c]
# Out:
#       Item  Price (Euro)
# 1     milk           1.0
# 2    chips           3.0
# 3  bananas           2.5

# %% [markdown]
# ## <span class="section" id="section_copy">4.</span> Modifying a `DataFrame`
#
# `DataFrame` objects are _mutable_.
# In this lesson we will only present two very basic ways of modifying a `DataFrame` object.

# %% [markdown]
# ### Changing a value in a `DataFrame`
#
# To change a value at a particular location of a data frame `df`,
# you can use an assignment to the selected item:
# ```python
# df.loc[row, column] = expression
# ```

# %%
df.loc[0, 'B'] = 'ACE'
df
# Out:
#    A      B      C
# 0  1    ACE  False
# 1  2    two   True
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# ### Changing values in a slice from a `DataFrame`
#
# Modifying values in data frame slices is a little bit cumbersome.
#
# > **IMPORTANT:** For reasons outside the scope of this course, if you want to operate on slices, it is recommended to **explicitly create a copy** of the slice.
#
# For example, let us take a look at the `df` data frame again:

# %%
df
# Out:
#    A      B      C
# 0  1    ACE  False
# 1  2    two   True
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# If we take a slice of the `df` data frame:

# %%
df_slice = df.loc[1:2].copy()
df_slice
# Out:
#    A      B      C
# 1  2    two   True
# 2  3  three  False

# %% [markdown]
# and modify the values in the first row of the slice:

# %%
df_slice.loc[1, 'A'] = 8
df_slice.loc[1, 'B'] = "EIGHT"
df_slice
# Out:
#    A      B      C
# 1  8  EIGHT   True
# 2  3  three  False

# %% [markdown]
# the original data frame will not be affected:

# %%
df
# Out:
#    A      B      C
# 0  1    ACE  False
# 1  2    two   True
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# ### Exercise <span class="exercise">4.a</span>
#
# Let us continue with the shopping list example:

# %%
prices = [2, 1, 3, 2.5, 1.5 ]
items  = ['bread', 'milk', 'chips', 'bananas', 'carrots']
df_shopping_list = pd.DataFrame( { 'Item': items, 'Price (Euro)': prices } )
df_shopping_list
# Out:
#       Item  Price (Euro)
# 0    bread           2.0
# 1     milk           1.0
# 2    chips           3.0
# 3  bananas           2.5
# 4  carrots           1.5

# %% [markdown]
# Change in the `df_shopping_list` data frame the price for the bananas to 2.0 Euro.

# %%
#// BEGIN_TODO [EDA_4a] Update banana price (1 point)

df_shopping_list.loc[3, 'Price (Euro)'] = 2.0

#// END_TODO [EDA_4a]
df_shopping_list
# Out:
#       Item  Price (Euro)
# 0    bread           2.0
# 1     milk           1.0
# 2    chips           3.0
# 3  bananas           2.0
# 4  carrots           1.5

# %% [markdown]
# ### Exercise <span class="exercise">4.b</span>
#
# Create a shorter shopping list by taking the rows 0 to 2 from the `df_shopping_list` and assign it to `df_shorter_list`. Change in `df_shorter_list` the price of chips to 2.7 Euro, making sure that the original `df_shopping_list` is not affected.

# %%
#// BEGIN_TODO [EDA_4b] A new shorter list (1 point)

#df_slice = df.loc[1:2].copy()
df_shorter_list = df_shopping_list.loc[0:2].copy()
df_shorter_list.loc[2, 'Price (Euro)'] = 2.7

#// END_TODO [EDA_4b]

df_shorter_list
# Out:
#     Item  Price (Euro)
# 0  bread           2.0
# 1   milk           1.0
# 2  chips           2.7

# %% [markdown]
# ##  <span class="section">5.</span> Reading data from a file into a `DataFrame`

# %% [markdown]
# In these lessons, we will mainly use the **comma-separated values** (**CSV**) format
# for storing simple data in a file.
#
# Our CSV files will (usually) have
#
# * one header line with column labels,
# * each row on a line of its own,
# * commas to separate the fields in each row
#     (in some cases, you may encounter semicolons or TABs),
# * strings enclosed in double quotes
#     (in some case, strings are not enclosed), and
# * floating-point numbers using a decimal point (not a comma).

# %% [markdown]
# The example file is named `country-data.csv`. It was adapted from this repository: https://github.com/lorey/list-of-countries. This file is located in the `datasets` directory.

# %%
file_countries = './datasets/country-data.csv'

# %% [markdown]
# We use the function **`pd.read_csv`** to load the data from that file into a `DataFrame`
# that we will name `country_data`.

# %%
country_data = pd.read_csv(file_countries)
country_data.head()
# Out:
#                    name alpha_3  tld continent           capital      area  \
# 0               Andorra     AND  .ad        EU  Andorra la Vella     468.0
# 1  United Arab Emirates     ARE  .ae        AS         Abu Dhabi   82880.0
# 2           Afghanistan     AFG  .af        AS             Kabul  647500.0
# 3   Antigua and Barbuda     ATG  .ag        NM        St. John's     443.0
# 4              Anguilla     AIA  .ai        NM        The Valley     102.0
#
#    population
# 0       84000
# 1     4975593
# 2    29121286
# 3       86754
# 4       13254

# %% [markdown]
# ### Exercise <span class="exercise">5.a</span>
#
# Show just the `'name'`, `'area'` and `'population'` columns for the first 10 rows of `country_data`.

# %%
#// BEGIN_TODO [EDA_5a] Name, area, and population for first 10 rows (1 point)

country_data.loc[0:10, ['name','area','population']]

#// END_TODO [EDA_5a]
# Out:
#                     name        area  population
# 0                Andorra       468.0       84000
# 1   United Arab Emirates     82880.0     4975593
# 2            Afghanistan    647500.0    29121286
# 3    Antigua and Barbuda       443.0       86754
# 4               Anguilla       102.0       13254
# 5                Albania     28748.0     2986952
# 6                Armenia     29800.0     2968000
# 7                 Angola   1246700.0    13068161
# 8             Antarctica  14000000.0           0
# 9              Argentina   2766890.0    41343201
# 10        American Samoa       199.0       57881

# %% [markdown]
# ### Exercise <span class="exercise">5.b</span>
#
# Get information on the data frame `country_data`, using one of the functions introduced earlier.

# %%
#// BEGIN_TODO [EDA_5b] Get information about country_data (1 point)

country_data.info()

#// END_TODO [EDA_5b]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
# name          251 non-null object
# alpha_3       251 non-null object
# tld           249 non-null object
# continent     251 non-null object
# capital       245 non-null object
# area          251 non-null float64
# population    251 non-null int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 13.8+ KB

# %% [markdown]
# We see that there are 251 rows.
# Therefore, some columns have missing values:
#
# * `tld` misses 2 values
# * `capital` misses 6 values
#
# These are the seven columns of data and their types:
#
# * `name` (string): country name in English
# * `alpha_3` (string): 3-letter ISO 3166-1 country code
# * `tld` (string): top-level domain in Domain Name System
# * `continent` (string): 2-letter continent code
# * `capital` (string): capital city in English
# * `area` (float): area in square kilometer
# * `population` (integer): population (measurement date/source unclear; cf. https://geonames.org/)

# %% [markdown]
# ##  <span class="section">6.</span> Summary statistics
#
# Summary statistics for **numeric columns** in a data frame `df`
# can be obtained by **`df.describe()`**:

# %%
country_data.describe()
# Out:
#                area    population
# count  2.510000e+02  2.510000e+02
# mean   5.972518e+05  2.734232e+07
# std    1.908368e+06  1.166406e+08
# min    0.000000e+00  0.000000e+00
# 25%    1.096000e+03  1.839045e+05
# 50%    6.458900e+04  4.252277e+06
# 75%    3.674280e+05  1.539375e+07
# max    1.710000e+07  1.330044e+09

# %% [markdown]
# To get summary statistics for **all columns** supply the argument **`include='all'`**:

# %%
country_data.describe(include='all')
# Out:
#              name alpha_3  tld continent   capital          area    population
# count         251     251  249       251       245  2.510000e+02  2.510000e+02
# unique        251     251  247         7       244           NaN           NaN
# top     Guatemala     VNM  .gp        AF  Kingston           NaN           NaN
# freq            1       1    3        58         2           NaN           NaN
# mean          NaN     NaN  NaN       NaN       NaN  5.972518e+05  2.734232e+07
# std           NaN     NaN  NaN       NaN       NaN  1.908368e+06  1.166406e+08
# min           NaN     NaN  NaN       NaN       NaN  0.000000e+00  0.000000e+00
# 25%           NaN     NaN  NaN       NaN       NaN  1.096000e+03  1.839045e+05
# 50%           NaN     NaN  NaN       NaN       NaN  6.458900e+04  4.252277e+06
# 75%           NaN     NaN  NaN       NaN       NaN  3.674280e+05  1.539375e+07
# max           NaN     NaN  NaN       NaN       NaN  1.710000e+07  1.330044e+09

# %% [markdown]
# > NOTE: **NaN** stands for **"Not a Number"** and represents a **missing value**,
# > also known as **not available** or **null value**.

# %% [markdown]
# From these summary statistics for the country data, we see that
#
# * names and alpha-3 codes are unique (maximum frequency equals 1)
# * 3 countries share the top-level domain `.gp`
# * there are 7 continents, and Africa has the most countries (58)
# * 2 capitals are named Kingston, and there are no other such duplicates

# %% [markdown]
# ### Separate statistics
#
# There are also functions to obtain separate statistics for `DataFrame df`:
#
# * **`df.count()`** : Return the **number** of values
# * **`df.sum()`** : Return the **sum** of the values
# * **`df.mean()`** : Return the **mean** of the values
# * **`df.std()`** : Return the **sample standard deviation** of the numeric values,
#     normalized by $N-1$, where $N$ is the number of values
# * **`df.min()`** : Return the **minimum** of the values
# * **`df.max()`** : Return the **maximum** of the values
# * **`df.median()`** : Return the **median** of the values
# * **`df.quantile(q)`** : Return the value at the given **percentile** `q`;
#     `q=0.5` is default, giving the **median**
#
# Notes:
#
# * **NaN/null values** are skipped by default.
# * If the data frame has more than one column with relevant data,
#     then a `Series` object is returned with the statistic for each column.

# %% [markdown]
# Let's compute the total _area_ and _population_:

# %%
country_data[['area', 'population']].sum()
# Out:
# area          1.499102e+08
# population    6.862922e+09
# dtype: float64

# %% [markdown]
# ### Exercise <span class="exercise">6.a</span>
#
# Count the number of values in the _capital_ column.

# %%
#// BEGIN_TODO [EDA_6a] Number of values in the 'capital' column (1 point)

country_data['capital'].count()

#// END_TODO [EDA_6a]
# Out:
# 245

# %% [markdown]
# ## <span class="section">7.</span> Sorting a `DataFrame`
#
# To sort a data frame `df` by the values in column `'c'` use **`df.sort_values(by='c')`**.
# Note that this does not modify the data frame,
# but rather returns a new data frame.
# A series is sorted by the same function,
# but it does not need the `by` argument.
#
# Here is the country data sorted by _area_:

# %%
country_data.sort_values(by='area')
# Out:
#                                      name alpha_3  tld continent  \
# 232  United States Minor Outlying Islands     UMI  .um        OC
# 236                               Vatican     VAT  .va        EU
# 138                                Monaco     MCO  .mc        EU
# 82                              Gibraltar     GIB  .gi        EU
# 220                               Tokelau     TKL  .tk        OC
# 38                          Cocos Islands     CCK  .cc        AS
# 211                          Sint Maarten     SXM  .sx        NM
# 25                       Saint Barthelemy     BLM  .gp        NM
# 169                                 Nauru     NRU  .nr        OC
# 227                                Tuvalu     TUV  .tv        OC
# 163                        Norfolk Island     NFK  .nf        OC
# 181                              Pitcairn     PCN  .pn        OC
# 33                          Bouvet Island     BVT  .bv        AN
# 26                                Bermuda     BMU  .bm        NM
# 141                          Saint Martin     MAF  .gp        NM
# 105        British Indian Ocean Territory     IOT  .io        AS
# 205                            San Marino     SMR  .sm        EU
# 80                               Guernsey     GGY  .gg        EU
# 152                            Montserrat     MSR  .ms        NM
# 4                                Anguilla     AIA  .ai        NM
# 110                                Jersey     JEY  .je        EU
# 53                       Christmas Island     CXR  .cx        AS
# 239                British Virgin Islands     VGB  .vg        NM
# 129                         Liechtenstein     LIE  .li        EU
# 143                      Marshall Islands     MHL  .mh        OC
# 13                                  Aruba     ABW  .aw        NM
# 10                         American Samoa     ASM  .as        OC
# 44                           Cook Islands     COK  .ck        OC
# 180             Saint Pierre and Miquelon     SPM  .pm        NM
# 148                                 Macao     MAC  .mo        AS
# ..                                    ...     ...  ...       ...
# 151                            Mauritania     MRT  .mr        AF
# 28                                Bolivia     BOL  .bo        SM
# 68                               Ethiopia     ETH  .et        AF
# 48                               Colombia     COL  .co        SM
# 247                          South Africa     ZAF  .za        AF
# 145                                  Mali     MLI  .ml        AF
# 7                                  Angola     AGO  .ao        AF
# 162                                 Niger     NER  .ne        AF
# 215                                  Chad     TCD  .td        AF
# 174                                  Peru     PER  .pe        SM
# 147                              Mongolia     MNG  .mn        AS
# 107                                  Iran     IRN  .ir        AS
# 136                                 Libya     LBY  .ly        AF
# 196                                 Sudan     SDN  .sd        AF
# 100                             Indonesia     IDN  .id        AS
# 193                          Saudi Arabia     SAU  .sa        AS
# 157                                Mexico     MEX  .mx        NM
# 83                              Greenland     GRL  .gl        NM
# 39       Democratic Republic of the Congo     COD  .cd        AF
# 61                                Algeria     DZA  .dz        AF
# 125                            Kazakhstan     KAZ  .kz        AS
# 9                               Argentina     ARG  .ar        SM
# 104                                 India     IND  .in        AS
# 12                              Australia     AUS  .au        OC
# 30                                 Brazil     BRA  .br        SM
# 47                                  China     CHN  .cn        AS
# 233                         United States     USA  .us        NM
# 37                                 Canada     CAN  .ca        NM
# 8                              Antarctica     ATA  .aq        AN
# 191                                Russia     RUS  .ru        EU
#
#               capital         area  population
# 232               NaN         0.00           0
# 236      Vatican City         0.44         921
# 138            Monaco         1.95       32965
# 82          Gibraltar         6.50       27884
# 220               NaN        10.00        1466
# 38        West Island        14.00         628
# 211       Philipsburg        21.00       37429
# 25           Gustavia        21.00        8450
# 169             Yaren        21.00       10065
# 227          Funafuti        26.00       10472
# 163          Kingston        34.60        1828
# 181         Adamstown        47.00          46
# 33                NaN        49.00           0
# 26           Hamilton        53.00       65365
# 141           Marigot        53.00       35925
# 105      Diego Garcia        60.00        4000
# 205        San Marino        61.20       31477
# 80      St Peter Port        78.00       65228
# 152          Plymouth       102.00        9341
# 4          The Valley       102.00       13254
# 110      Saint Helier       116.00       90812
# 53   Flying Fish Cove       135.00        1500
# 239         Road Town       153.00       21730
# 129             Vaduz       160.00       35000
# 143            Majuro       181.30       65859
# 13         Oranjestad       193.00       71566
# 10          Pago Pago       199.00       57881
# 44             Avarua       240.00       21388
# 180      Saint-Pierre       242.00        7012
# 148             Macao       254.00      449198
# ..                ...          ...         ...
# 151        Nouakchott   1030700.00     3205060
# 28              Sucre   1098580.00     9947418
# 68        Addis Ababa   1127127.00    88013491
# 48             Bogota   1138910.00    47790000
# 247          Pretoria   1219912.00    49000000
# 145            Bamako   1240000.00    13796354
# 7              Luanda   1246700.00    13068161
# 162            Niamey   1267000.00    15878271
# 215         N'Djamena   1284000.00    10543464
# 174              Lima   1285220.00    29907003
# 147        Ulan Bator   1565000.00     3086918
# 107            Tehran   1648000.00    76923300
# 136           Tripoli   1759540.00     6461454
# 196          Khartoum   1861484.00    35000000
# 100           Jakarta   1919440.00   242968342
# 193            Riyadh   1960582.00    25731776
# 157       Mexico City   1972550.00   112468855
# 83               Nuuk   2166086.00       56375
# 39           Kinshasa   2345410.00    70916439
# 61            Algiers   2381740.00    34586184
# 125            Astana   2717300.00    15340000
# 9        Buenos Aires   2766890.00    41343201
# 104         New Delhi   3287590.00  1173108018
# 12           Canberra   7686850.00    21515754
# 30           Brasilia   8511965.00   201103330
# 47            Beijing   9596960.00  1330044000
# 233        Washington   9629091.00   310232863
# 37             Ottawa   9984670.00    33679000
# 8                 NaN  14000000.00           0
# 191            Moscow  17100000.00   140702000
#
# [251 rows x 7 columns]

# %% [markdown]
# To sort in **descending order**, supply the argument **`ascending=False`**:

# %%
country_data.sort_values(by='area', ascending=False)
# Out:
#                                      name alpha_3  tld continent  \
# 191                                Russia     RUS  .ru        EU
# 8                              Antarctica     ATA  .aq        AN
# 37                                 Canada     CAN  .ca        NM
# 233                         United States     USA  .us        NM
# 47                                  China     CHN  .cn        AS
# 30                                 Brazil     BRA  .br        SM
# 12                              Australia     AUS  .au        OC
# 104                                 India     IND  .in        AS
# 9                               Argentina     ARG  .ar        SM
# 125                            Kazakhstan     KAZ  .kz        AS
# 61                                Algeria     DZA  .dz        AF
# 39       Democratic Republic of the Congo     COD  .cd        AF
# 83                              Greenland     GRL  .gl        NM
# 157                                Mexico     MEX  .mx        NM
# 193                          Saudi Arabia     SAU  .sa        AS
# 100                             Indonesia     IDN  .id        AS
# 196                                 Sudan     SDN  .sd        AF
# 136                                 Libya     LBY  .ly        AF
# 107                                  Iran     IRN  .ir        AS
# 147                              Mongolia     MNG  .mn        AS
# 174                                  Peru     PER  .pe        SM
# 215                                  Chad     TCD  .td        AF
# 162                                 Niger     NER  .ne        AF
# 7                                  Angola     AGO  .ao        AF
# 145                                  Mali     MLI  .ml        AF
# 247                          South Africa     ZAF  .za        AF
# 48                               Colombia     COL  .co        SM
# 68                               Ethiopia     ETH  .et        AF
# 28                                Bolivia     BOL  .bo        SM
# 151                            Mauritania     MRT  .mr        AF
# ..                                    ...     ...  ...       ...
# 148                                 Macao     MAC  .mo        AS
# 180             Saint Pierre and Miquelon     SPM  .pm        NM
# 44                           Cook Islands     COK  .ck        OC
# 10                         American Samoa     ASM  .as        OC
# 13                                  Aruba     ABW  .aw        NM
# 143                      Marshall Islands     MHL  .mh        OC
# 129                         Liechtenstein     LIE  .li        EU
# 239                British Virgin Islands     VGB  .vg        NM
# 53                       Christmas Island     CXR  .cx        AS
# 110                                Jersey     JEY  .je        EU
# 4                                Anguilla     AIA  .ai        NM
# 152                            Montserrat     MSR  .ms        NM
# 80                               Guernsey     GGY  .gg        EU
# 205                            San Marino     SMR  .sm        EU
# 105        British Indian Ocean Territory     IOT  .io        AS
# 141                          Saint Martin     MAF  .gp        NM
# 26                                Bermuda     BMU  .bm        NM
# 33                          Bouvet Island     BVT  .bv        AN
# 181                              Pitcairn     PCN  .pn        OC
# 163                        Norfolk Island     NFK  .nf        OC
# 227                                Tuvalu     TUV  .tv        OC
# 211                          Sint Maarten     SXM  .sx        NM
# 169                                 Nauru     NRU  .nr        OC
# 25                       Saint Barthelemy     BLM  .gp        NM
# 38                          Cocos Islands     CCK  .cc        AS
# 220                               Tokelau     TKL  .tk        OC
# 82                              Gibraltar     GIB  .gi        EU
# 138                                Monaco     MCO  .mc        EU
# 236                               Vatican     VAT  .va        EU
# 232  United States Minor Outlying Islands     UMI  .um        OC
#
#               capital         area  population
# 191            Moscow  17100000.00   140702000
# 8                 NaN  14000000.00           0
# 37             Ottawa   9984670.00    33679000
# 233        Washington   9629091.00   310232863
# 47            Beijing   9596960.00  1330044000
# 30           Brasilia   8511965.00   201103330
# 12           Canberra   7686850.00    21515754
# 104         New Delhi   3287590.00  1173108018
# 9        Buenos Aires   2766890.00    41343201
# 125            Astana   2717300.00    15340000
# 61            Algiers   2381740.00    34586184
# 39           Kinshasa   2345410.00    70916439
# 83               Nuuk   2166086.00       56375
# 157       Mexico City   1972550.00   112468855
# 193            Riyadh   1960582.00    25731776
# 100           Jakarta   1919440.00   242968342
# 196          Khartoum   1861484.00    35000000
# 136           Tripoli   1759540.00     6461454
# 107            Tehran   1648000.00    76923300
# 147        Ulan Bator   1565000.00     3086918
# 174              Lima   1285220.00    29907003
# 215         N'Djamena   1284000.00    10543464
# 162            Niamey   1267000.00    15878271
# 7              Luanda   1246700.00    13068161
# 145            Bamako   1240000.00    13796354
# 247          Pretoria   1219912.00    49000000
# 48             Bogota   1138910.00    47790000
# 68        Addis Ababa   1127127.00    88013491
# 28              Sucre   1098580.00     9947418
# 151        Nouakchott   1030700.00     3205060
# ..                ...          ...         ...
# 148             Macao       254.00      449198
# 180      Saint-Pierre       242.00        7012
# 44             Avarua       240.00       21388
# 10          Pago Pago       199.00       57881
# 13         Oranjestad       193.00       71566
# 143            Majuro       181.30       65859
# 129             Vaduz       160.00       35000
# 239         Road Town       153.00       21730
# 53   Flying Fish Cove       135.00        1500
# 110      Saint Helier       116.00       90812
# 4          The Valley       102.00       13254
# 152          Plymouth       102.00        9341
# 80      St Peter Port        78.00       65228
# 205        San Marino        61.20       31477
# 105      Diego Garcia        60.00        4000
# 141           Marigot        53.00       35925
# 26           Hamilton        53.00       65365
# 33                NaN        49.00           0
# 181         Adamstown        47.00          46
# 163          Kingston        34.60        1828
# 227          Funafuti        26.00       10472
# 211       Philipsburg        21.00       37429
# 169             Yaren        21.00       10065
# 25           Gustavia        21.00        8450
# 38        West Island        14.00         628
# 220               NaN        10.00        1466
# 82          Gibraltar         6.50       27884
# 138            Monaco         1.95       32965
# 236      Vatican City         0.44         921
# 232               NaN         0.00           0
#
# [251 rows x 7 columns]

# %% [markdown]
# > A data frame can be **sorted in place**,
# > that is, the data frame is modified,
# > rather than returning a new data frame.
# > This is achieved by supplying the argument **`inplace=True`**,
# > but is not recommended (rather, assign the result to a new variable).

# %% [markdown]
# To **sort on multiple columns**, provide a _list of column labels_:

# %%
country_data.sort_values(by=['continent', 'name'])
# Out:
#                                      name alpha_3  tld continent  \
# 61                                Algeria     DZA  .dz        AF
# 7                                  Angola     AGO  .ao        AF
# 24                                  Benin     BEN  .bj        AF
# 34                               Botswana     BWA  .bw        AF
# 20                           Burkina Faso     BFA  .bf        AF
# 23                                Burundi     BDI  .bi        AF
# 46                               Cameroon     CMR  .cm        AF
# 51                             Cape Verde     CPV  .cv        AF
# 40               Central African Republic     CAF  .cf        AF
# 215                                  Chad     TCD  .td        AF
# 118                               Comoros     COM  .km        AF
# 39       Democratic Republic of the Congo     COD  .cd        AF
# 57                               Djibouti     DJI  .dj        AF
# 64                                  Egypt     EGY  .eg        AF
# 87                      Equatorial Guinea     GNQ  .gq        AF
# 66                                Eritrea     ERI  .er        AF
# 68                               Ethiopia     ETH  .et        AF
# 75                                  Gabon     GAB  .ga        AF
# 84                                 Gambia     GMB  .gm        AF
# 81                                  Ghana     GHA  .gh        AF
# 85                                 Guinea     GIN  .gn        AF
# 92                          Guinea-Bissau     GNB  .gw        AF
# 43                            Ivory Coast     CIV  .ci        AF
# 114                                 Kenya     KEN  .ke        AF
# 132                               Lesotho     LSO  .ls        AF
# 131                               Liberia     LBR  .lr        AF
# 136                                 Libya     LBY  .ly        AF
# 142                            Madagascar     MDG  .mg        AF
# 156                                Malawi     MWI  .mw        AF
# 145                                  Mali     MLI  .ml        AF
# ..                                    ...     ...  ...       ...
# 161                         New Caledonia     NCL  .nc        OC
# 171                           New Zealand     NZL  .nz        OC
# 170                                  Niue     NIU  .nu        OC
# 163                        Norfolk Island     NFK  .nf        OC
# 149              Northern Mariana Islands     MNP  .mp        OC
# 185                                 Palau     PLW  .pw        OC
# 176                      Papua New Guinea     PNG  .pg        OC
# 181                              Pitcairn     PCN  .pn        OC
# 244                                 Samoa     WSM  .ws        OC
# 194                       Solomon Islands     SLB  .sb        OC
# 220                               Tokelau     TKL  .tk        OC
# 224                                 Tonga     TON  .to        OC
# 227                                Tuvalu     TUV  .tv        OC
# 232  United States Minor Outlying Islands     UMI  .um        OC
# 242                               Vanuatu     VUT  .vu        OC
# 243                     Wallis and Futuna     WLF  .wf        OC
# 9                               Argentina     ARG  .ar        SM
# 28                                Bolivia     BOL  .bo        SM
# 30                                 Brazil     BRA  .br        SM
# 45                                  Chile     CHL  .cl        SM
# 48                               Colombia     COL  .co        SM
# 62                                Ecuador     ECU  .ec        SM
# 71                       Falkland Islands     FLK  .fk        SM
# 79                          French Guiana     GUF  .gf        SM
# 93                                 Guyana     GUY  .gy        SM
# 186                              Paraguay     PRY  .py        SM
# 174                                  Peru     PER  .pe        SM
# 208                              Suriname     SUR  .sr        SM
# 234                               Uruguay     URY  .uy        SM
# 238                             Venezuela     VEN  .ve        SM
#
#           capital       area  population
# 61        Algiers  2381740.0    34586184
# 7          Luanda  1246700.0    13068161
# 24     Porto-Novo   112620.0     9056010
# 34       Gaborone   600370.0     2029307
# 20    Ouagadougou   274200.0    16241811
# 23      Bujumbura    27830.0     9863117
# 46        Yaounde   475440.0    19294149
# 51          Praia     4033.0      508659
# 40         Bangui   622984.0     4844927
# 215     N'Djamena  1284000.0    10543464
# 118        Moroni     2170.0      773407
# 39       Kinshasa  2345410.0    70916439
# 57       Djibouti    23000.0      740528
# 64          Cairo  1001450.0    80471869
# 87         Malabo    28051.0     1014999
# 66         Asmara   121320.0     5792984
# 68    Addis Ababa  1127127.0    88013491
# 75     Libreville   267667.0     1545255
# 84         Banjul    11300.0     1593256
# 81          Accra   239460.0    24339838
# 85        Conakry   245857.0    10324025
# 92         Bissau    36120.0     1565126
# 43   Yamoussoukro   322460.0    21058798
# 114       Nairobi   582650.0    40046566
# 132        Maseru    30355.0     1919552
# 131      Monrovia   111370.0     3685076
# 136       Tripoli  1759540.0     6461454
# 142  Antananarivo   587040.0    21281844
# 156      Lilongwe   118480.0    15447500
# 145        Bamako  1240000.0    13796354
# ..            ...        ...         ...
# 161        Noumea    19060.0      216494
# 171    Wellington   268680.0     4252277
# 170         Alofi      260.0        2166
# 163      Kingston       34.6        1828
# 149        Saipan      477.0       53883
# 185      Melekeok      458.0       19907
# 176  Port Moresby   462840.0     6064515
# 181     Adamstown       47.0          46
# 244          Apia     2944.0      192001
# 194       Honiara    28450.0      559198
# 220           NaN       10.0        1466
# 224    Nuku'alofa      748.0      122580
# 227      Funafuti       26.0       10472
# 232           NaN        0.0           0
# 242     Port Vila    12200.0      221552
# 243      Mata Utu      274.0       16025
# 9    Buenos Aires  2766890.0    41343201
# 28          Sucre  1098580.0     9947418
# 30       Brasilia  8511965.0   201103330
# 45       Santiago   756950.0    16746491
# 48         Bogota  1138910.0    47790000
# 62          Quito   283560.0    14790608
# 71        Stanley    12173.0        2638
# 79        Cayenne    91000.0      195506
# 93     Georgetown   214970.0      748486
# 186      Asuncion   406750.0     6375830
# 174          Lima  1285220.0    29907003
# 208    Paramaribo   163270.0      492829
# 234    Montevideo   176220.0     3477000
# 238       Caracas   912050.0    27223228
#
# [251 rows x 7 columns]

# %% [markdown]
# As you can see, the index (left-most column) labels are sorted along as well.
# If you want to have a new index for the result, in sorted order,
# then you can use the function **`reset_index()`**.
# The old index is preserved as well in the column labeled `'index'`.
#
# Let's sort the country data by _population_,
# reset the index, and assign the result to variable `country_data_sorted_by_pop`:

# %%
country_data_sorted_by_pop = country_data.sort_values(by='population', ascending=False).reset_index()
country_data_sorted_by_pop
# Out:
#      index                                          name alpha_3  tld  \
# 0       47                                         China     CHN  .cn
# 1      104                                         India     IND  .in
# 2      233                                 United States     USA  .us
# 3      100                                     Indonesia     IDN  .id
# 4       30                                        Brazil     BRA  .br
# 5      178                                      Pakistan     PAK  .pk
# 6       18                                    Bangladesh     BGD  .bd
# 7      164                                       Nigeria     NGA  .ng
# 8      191                                        Russia     RUS  .ru
# 9      113                                         Japan     JPN  .jp
# 10     157                                        Mexico     MEX  .mx
# 11     177                                   Philippines     PHL  .ph
# 12     241                                       Vietnam     VNM  .vn
# 13      68                                      Ethiopia     ETH  .et
# 14      56                                       Germany     DEU  .de
# 15      64                                         Egypt     EGY  .eg
# 16     225                                        Turkey     TUR  .tr
# 17     107                                          Iran     IRN  .ir
# 18      39              Democratic Republic of the Congo     COD  .cd
# 19     218                                      Thailand     THA  .th
# 20      74                                        France     FRA  .fr
# 21      76                                United Kingdom     GBR  .uk
# 22     109                                         Italy     ITA  .it
# 23     146                                       Myanmar     MMR  .mm
# 24     247                                  South Africa     ZAF  .za
# 25     121                                   South Korea     KOR  .kr
# 26      48                                      Colombia     COL  .co
# 27      67                                         Spain     ESP  .es
# 28     230                                       Ukraine     UKR  .ua
# 29     229                                      Tanzania     TZA  .tz
# ..     ...                                           ...     ...  ...
# 221     14                                 Aland Islands     ALA  .ax
# 222    239                        British Virgin Islands     VGB  .vg
# 223     44                                  Cook Islands     COK  .ck
# 224    214                      Turks and Caicos Islands     TCA  .tc
# 225    185                                         Palau     PLW  .pw
# 226     29            Bonaire, Saint Eustatius and Saba      BES  .bq
# 227    243                             Wallis and Futuna     WLF  .wf
# 228      4                                      Anguilla     AIA  .ai
# 229    227                                        Tuvalu     TUV  .tv
# 230    169                                         Nauru     NRU  .nr
# 231    152                                    Montserrat     MSR  .ms
# 232     25                              Saint Barthelemy     BLM  .gp
# 233    200                                  Saint Helena     SHN  .sh
# 234    180                     Saint Pierre and Miquelon     SPM  .pm
# 235    105                British Indian Ocean Territory     IOT  .io
# 236     71                              Falkland Islands     FLK  .fk
# 237    202                        Svalbard and Jan Mayen     SJM  .sj
# 238    170                                          Niue     NIU  .nu
# 239    163                                Norfolk Island     NFK  .nf
# 240     53                              Christmas Island     CXR  .cx
# 241    220                                       Tokelau     TKL  .tk
# 242    236                                       Vatican     VAT  .va
# 243     38                                 Cocos Islands     CCK  .cc
# 244    216                   French Southern Territories     ATF  .tf
# 245    181                                      Pitcairn     PCN  .pn
# 246     89  South Georgia and the South Sandwich Islands     SGS  .gs
# 247    232          United States Minor Outlying Islands     UMI  .um
# 248     33                                 Bouvet Island     BVT  .bv
# 249      8                                    Antarctica     ATA  .aq
# 250     95             Heard Island and McDonald Islands     HMD  .hm
#
#     continent            capital         area  population
# 0          AS            Beijing   9596960.00  1330044000
# 1          AS          New Delhi   3287590.00  1173108018
# 2          NM         Washington   9629091.00   310232863
# 3          AS            Jakarta   1919440.00   242968342
# 4          SM           Brasilia   8511965.00   201103330
# 5          AS          Islamabad    803940.00   184404791
# 6          AS              Dhaka    144000.00   156118464
# 7          AF              Abuja    923768.00   154000000
# 8          EU             Moscow  17100000.00   140702000
# 9          AS              Tokyo    377835.00   127288000
# 10         NM        Mexico City   1972550.00   112468855
# 11         AS             Manila    300000.00    99900177
# 12         AS              Hanoi    329560.00    89571130
# 13         AF        Addis Ababa   1127127.00    88013491
# 14         EU             Berlin    357021.00    81802257
# 15         AF              Cairo   1001450.00    80471869
# 16         AS             Ankara    780580.00    77804122
# 17         AS             Tehran   1648000.00    76923300
# 18         AF           Kinshasa   2345410.00    70916439
# 19         AS            Bangkok    514000.00    67089500
# 20         EU              Paris    547030.00    64768389
# 21         EU             London    244820.00    62348447
# 22         EU               Rome    301230.00    60340328
# 23         AS        Nay Pyi Taw    678500.00    53414374
# 24         AF           Pretoria   1219912.00    49000000
# 25         AS              Seoul     98480.00    48422644
# 26         SM             Bogota   1138910.00    47790000
# 27         EU             Madrid    504782.00    46505963
# 28         EU               Kiev    603700.00    45415596
# 29         AF             Dodoma    945087.00    41892895
# ..        ...                ...          ...         ...
# 221        EU          Mariehamn      1580.00       26711
# 222        NM          Road Town       153.00       21730
# 223        OC             Avarua       240.00       21388
# 224        NM      Cockburn Town       430.00       20556
# 225        OC           Melekeok       458.00       19907
# 226        NM                NaN       328.00       18012
# 227        OC           Mata Utu       274.00       16025
# 228        NM         The Valley       102.00       13254
# 229        OC           Funafuti        26.00       10472
# 230        OC              Yaren        21.00       10065
# 231        NM           Plymouth       102.00        9341
# 232        NM           Gustavia        21.00        8450
# 233        AF          Jamestown       410.00        7460
# 234        NM       Saint-Pierre       242.00        7012
# 235        AS       Diego Garcia        60.00        4000
# 236        SM            Stanley     12173.00        2638
# 237        EU       Longyearbyen     62049.00        2550
# 238        OC              Alofi       260.00        2166
# 239        OC           Kingston        34.60        1828
# 240        AS   Flying Fish Cove       135.00        1500
# 241        OC                NaN        10.00        1466
# 242        EU       Vatican City         0.44         921
# 243        AS        West Island        14.00         628
# 244        AN  Port-aux-Francais      7829.00         140
# 245        OC          Adamstown        47.00          46
# 246        AN          Grytviken      3903.00          30
# 247        OC                NaN         0.00           0
# 248        AN                NaN        49.00           0
# 249        AN                NaN  14000000.00           0
# 250        AN                NaN       412.00           0
#
# [251 rows x 8 columns]

# %% [markdown]
# ### Exercise <span class="exercise">7.a</span>
#
# Sort the data on _area_ in descending order,
# and show the _name_ and _area_ for the first 10 rows.

# %%
#// BEGIN_TODO [EDA_7a] Name and area of first 10 rows after sorting on area (1 point)

country_data_row = country_data.sort_values(by='area', ascending=False).reset_index()
country_data_row.loc[0:9]


#// END_TODO [EDA_7a]
# Out:
#    index           name alpha_3  tld continent       capital        area  \
# 0    191         Russia     RUS  .ru        EU        Moscow  17100000.0
# 1      8     Antarctica     ATA  .aq        AN           NaN  14000000.0
# 2     37         Canada     CAN  .ca        NM        Ottawa   9984670.0
# 3    233  United States     USA  .us        NM    Washington   9629091.0
# 4     47          China     CHN  .cn        AS       Beijing   9596960.0
# 5     30         Brazil     BRA  .br        SM      Brasilia   8511965.0
# 6     12      Australia     AUS  .au        OC      Canberra   7686850.0
# 7    104          India     IND  .in        AS     New Delhi   3287590.0
# 8      9      Argentina     ARG  .ar        SM  Buenos Aires   2766890.0
# 9    125     Kazakhstan     KAZ  .kz        AS        Astana   2717300.0
#
#    population
# 0   140702000
# 1           0
# 2    33679000
# 3   310232863
# 4  1330044000
# 5   201103330
# 6    21515754
# 7  1173108018
# 8    41343201
# 9    15340000

# %% [markdown]
# ## <span class="section">8.</span> Computing values from a `DataFrame`
#
# You can apply **arithmetic operations** on entire data frames or series,
# such as selected columns.
#
# Let's calculate the _population density_ (_population_ divided by _area_) for each country:

# %%
country_data['population'] / country_data['area']
# Out:
# 0       179.487179
# 1        60.033699
# 2        44.974959
# 3       195.832957
# 4       129.941176
# 5       103.901211
# 6        99.597315
# 7        10.482202
# 8         0.000000
# 9        14.942119
# 10      290.859296
# 11       97.843974
# 12        2.799034
# 13      370.808290
# 14       16.905696
# 15       95.883510
# 16       89.772927
# 17      662.767981
# 18     1084.156000
# 19      340.970174
# 20       59.233446
# 21       64.455730
# 22     1109.780451
# 23      354.405929
# 24       80.412094
# 25      402.380952
# 26     1233.301887
# 27       68.462218
# 28        9.054796
# 29       54.914634
#           ...
# 221      76.939095
# 222      10.122754
# 223      64.721136
# 224     163.877005
# 225      99.674757
# 226     239.604329
# 227     402.769231
# 228     636.308616
# 229      44.327025
# 230      75.228749
# 231     141.495857
# 232            NaN
# 233      32.218292
# 234      19.731018
# 235      62.283724
# 236    2093.181818
# 237     267.910026
# 238      29.848394
# 239     142.026144
# 240     308.829545
# 241     271.790053
# 242      18.160000
# 243      58.485401
# 244      65.217731
# 245      44.501318
# 246     425.245989
# 247      40.166832
# 248      17.884739
# 249      33.440012
# 250     312.500000
# Length: 251, dtype: float64

# %% [markdown]
# ### Adding a new column to a `DataFrame`
#
# It is more useful to combine the computed population density with the existing data,
# by **adding a new column** with the computed density values.
# We put it in a new column labeled `'density'` as follows:

# %%
country_data['density'] = country_data['population'] / country_data['area']
country_data
# Out:
#                                      name alpha_3  tld continent  \
# 0                                 Andorra     AND  .ad        EU
# 1                    United Arab Emirates     ARE  .ae        AS
# 2                             Afghanistan     AFG  .af        AS
# 3                     Antigua and Barbuda     ATG  .ag        NM
# 4                                Anguilla     AIA  .ai        NM
# 5                                 Albania     ALB  .al        EU
# 6                                 Armenia     ARM  .am        AS
# 7                                  Angola     AGO  .ao        AF
# 8                              Antarctica     ATA  .aq        AN
# 9                               Argentina     ARG  .ar        SM
# 10                         American Samoa     ASM  .as        OC
# 11                                Austria     AUT  .at        EU
# 12                              Australia     AUS  .au        OC
# 13                                  Aruba     ABW  .aw        NM
# 14                          Aland Islands     ALA  .ax        EU
# 15                             Azerbaijan     AZE  .az        AS
# 16                 Bosnia and Herzegovina     BIH  .ba        EU
# 17                               Barbados     BRB  .bb        NM
# 18                             Bangladesh     BGD  .bd        AS
# 19                                Belgium     BEL  .be        EU
# 20                           Burkina Faso     BFA  .bf        AF
# 21                               Bulgaria     BGR  .bg        EU
# 22                                Bahrain     BHR  .bh        AS
# 23                                Burundi     BDI  .bi        AF
# 24                                  Benin     BEN  .bj        AF
# 25                       Saint Barthelemy     BLM  .gp        NM
# 26                                Bermuda     BMU  .bm        NM
# 27                                 Brunei     BRN  .bn        AS
# 28                                Bolivia     BOL  .bo        SM
# 29     Bonaire, Saint Eustatius and Saba      BES  .bq        NM
# ..                                    ...     ...  ...       ...
# 221                            East Timor     TLS  .tl        OC
# 222                          Turkmenistan     TKM  .tm        AS
# 223                               Tunisia     TUN  .tn        AF
# 224                                 Tonga     TON  .to        OC
# 225                                Turkey     TUR  .tr        AS
# 226                   Trinidad and Tobago     TTO  .tt        NM
# 227                                Tuvalu     TUV  .tv        OC
# 228                                Taiwan     TWN  .tw        AS
# 229                              Tanzania     TZA  .tz        AF
# 230                               Ukraine     UKR  .ua        EU
# 231                                Uganda     UGA  .ug        AF
# 232  United States Minor Outlying Islands     UMI  .um        OC
# 233                         United States     USA  .us        NM
# 234                               Uruguay     URY  .uy        SM
# 235                            Uzbekistan     UZB  .uz        AS
# 236                               Vatican     VAT  .va        EU
# 237      Saint Vincent and the Grenadines     VCT  .vc        NM
# 238                             Venezuela     VEN  .ve        SM
# 239                British Virgin Islands     VGB  .vg        NM
# 240                   U.S. Virgin Islands     VIR  .vi        NM
# 241                               Vietnam     VNM  .vn        AS
# 242                               Vanuatu     VUT  .vu        OC
# 243                     Wallis and Futuna     WLF  .wf        OC
# 244                                 Samoa     WSM  .ws        OC
# 245                                 Yemen     YEM  .ye        AS
# 246                               Mayotte     MYT  .yt        AF
# 247                          South Africa     ZAF  .za        AF
# 248                                Zambia     ZMB  .zm        AF
# 249                              Zimbabwe     ZWE  .zw        AF
# 250                  Netherlands Antilles     ANT  .an        NM
#
#                  capital         area  population      density
# 0       Andorra la Vella       468.00       84000   179.487179
# 1              Abu Dhabi     82880.00     4975593    60.033699
# 2                  Kabul    647500.00    29121286    44.974959
# 3             St. John's       443.00       86754   195.832957
# 4             The Valley       102.00       13254   129.941176
# 5                 Tirana     28748.00     2986952   103.901211
# 6                Yerevan     29800.00     2968000    99.597315
# 7                 Luanda   1246700.00    13068161    10.482202
# 8                    NaN  14000000.00           0     0.000000
# 9           Buenos Aires   2766890.00    41343201    14.942119
# 10             Pago Pago       199.00       57881   290.859296
# 11                Vienna     83858.00     8205000    97.843974
# 12              Canberra   7686850.00    21515754     2.799034
# 13            Oranjestad       193.00       71566   370.808290
# 14             Mariehamn      1580.00       26711    16.905696
# 15                  Baku     86600.00     8303512    95.883510
# 16              Sarajevo     51129.00     4590000    89.772927
# 17            Bridgetown       431.00      285653   662.767981
# 18                 Dhaka    144000.00   156118464  1084.156000
# 19              Brussels     30510.00    10403000   340.970174
# 20           Ouagadougou    274200.00    16241811    59.233446
# 21                 Sofia    110910.00     7148785    64.455730
# 22                Manama       665.00      738004  1109.780451
# 23             Bujumbura     27830.00     9863117   354.405929
# 24            Porto-Novo    112620.00     9056010    80.412094
# 25              Gustavia        21.00        8450   402.380952
# 26              Hamilton        53.00       65365  1233.301887
# 27   Bandar Seri Begawan      5770.00      395027    68.462218
# 28                 Sucre   1098580.00     9947418     9.054796
# 29                   NaN       328.00       18012    54.914634
# ..                   ...          ...         ...          ...
# 221                 Dili     15007.00     1154625    76.939095
# 222             Ashgabat    488100.00     4940916    10.122754
# 223                Tunis    163610.00    10589025    64.721136
# 224           Nuku'alofa       748.00      122580   163.877005
# 225               Ankara    780580.00    77804122    99.674757
# 226        Port of Spain      5128.00     1228691   239.604329
# 227             Funafuti        26.00       10472   402.769231
# 228               Taipei     35980.00    22894384   636.308616
# 229               Dodoma    945087.00    41892895    44.327025
# 230                 Kiev    603700.00    45415596    75.228749
# 231              Kampala    236040.00    33398682   141.495857
# 232                  NaN         0.00           0          NaN
# 233           Washington   9629091.00   310232863    32.218292
# 234           Montevideo    176220.00     3477000    19.731018
# 235             Tashkent    447400.00    27865738    62.283724
# 236         Vatican City         0.44         921  2093.181818
# 237            Kingstown       389.00      104217   267.910026
# 238              Caracas    912050.00    27223228    29.848394
# 239            Road Town       153.00       21730   142.026144
# 240     Charlotte Amalie       352.00      108708   308.829545
# 241                Hanoi    329560.00    89571130   271.790053
# 242            Port Vila     12200.00      221552    18.160000
# 243             Mata Utu       274.00       16025    58.485401
# 244                 Apia      2944.00      192001    65.217731
# 245                Sanaa    527970.00    23495361    44.501318
# 246            Mamoudzou       374.00      159042   425.245989
# 247             Pretoria   1219912.00    49000000    40.166832
# 248               Lusaka    752614.00    13460305    17.884739
# 249               Harare    390580.00    13061000    33.440012
# 250           Willemstad       960.00      300000   312.500000
#
# [251 rows x 8 columns]

# %% [markdown]
# ### Exercise <span class="exercise">8.a</span>
#
# Add a new column labeled `specific_area` with the _specific area_
# (_area_ divided by _population_) **expressed in $\mathrm{m}^2$ per person**,
# and show the first five rows of the data frame.
#
# Hint: The default value of `head()` is five.

# %%
#// BEGIN_TODO [EDA_8a] Add 'specific_area' column (1 point)

country_data['specific area'] = country_data['area']/country_data['population']
country_data.head()

#// END_TODO [EDA_8a]
# Out:
#                    name alpha_3  tld continent           capital      area  \
# 0               Andorra     AND  .ad        EU  Andorra la Vella     468.0
# 1  United Arab Emirates     ARE  .ae        AS         Abu Dhabi   82880.0
# 2           Afghanistan     AFG  .af        AS             Kabul  647500.0
# 3   Antigua and Barbuda     ATG  .ag        NM        St. John's     443.0
# 4              Anguilla     AIA  .ai        NM        The Valley     102.0
#
#    population     density  specific area
# 0       84000  179.487179       0.005571
# 1     4975593   60.033699       0.016657
# 2    29121286   44.974959       0.022235
# 3       86754  195.832957       0.005106
# 4       13254  129.941176       0.007696

# %% [markdown]
# ### Exercise <span class="exercise">8.b</span>
#
# Show the result of sorting `country_data` in _descending_ order on _density_:

# %%
#// BEGIN_TODO [EDA_8b] Sort on density in descending order (1 point)

country_data_sortedbydensity = country_data.sort_values(by='density', ascending=False).reset_index()
country_data_sortedbydensity

#// END_TODO [EDA_8b]
# Out:
#      index                                          name alpha_3  tld  \
# 0      138                                        Monaco     MCO  .mc
# 1      199                                     Singapore     SGP  .sg
# 2       94                                     Hong Kong     HKG  .hk
# 3       82                                     Gibraltar     GIB  .gi
# 4      236                                       Vatican     VAT  .va
# 5      211                                  Sint Maarten     SXM  .sx
# 6      148                                         Macao     MAC  .mo
# 7      155                                      Maldives     MDV  .mv
# 8      153                                         Malta     MLT  .mt
# 9       26                                       Bermuda     BMU  .bm
# 10      22                                       Bahrain     BHR  .bh
# 11      18                                    Bangladesh     BGD  .bd
# 12      80                                      Guernsey     GGY  .gg
# 13     110                                        Jersey     JEY  .je
# 14     141                                  Saint Martin     MAF  .gp
# 15      17                                      Barbados     BRB  .bb
# 16     183                         Palestinian Territory     PSE  .ps
# 17     228                                        Taiwan     TWN  .tw
# 18     154                                     Mauritius     MUS  .mu
# 19     205                                    San Marino     SMR  .sm
# 20     121                                   South Korea     KOR  .kr
# 21     169                                         Nauru     NRU  .nr
# 22     182                                   Puerto Rico     PRI  .pr
# 23     246                                       Mayotte     MYT  .yt
# 24     192                                        Rwanda     RWA  .rw
# 25     227                                        Tuvalu     TUV  .tv
# 26      25                              Saint Barthelemy     BLM  .gp
# 27     166                                   Netherlands     NLD  .nl
# 28     127                                       Lebanon     LBN  .lb
# 29     150                                    Martinique     MTQ  .mq
# ..     ...                                           ...     ...  ...
# 221     28                                       Bolivia     BOL  .bo
# 222     41                         Republic of the Congo     COG  .cg
# 223    170                                          Niue     NIU  .nu
# 224    191                                        Russia     RUS  .ru
# 225    215                                          Chad     TCD  .td
# 226     40                      Central African Republic     CAF  .cf
# 227     75                                         Gabon     GAB  .ga
# 228    125                                    Kazakhstan     KAZ  .kz
# 229    136                                         Libya     LBY  .ly
# 230     93                                        Guyana     GUY  .gy
# 231     34                                      Botswana     BWA  .bw
# 232     37                                        Canada     CAN  .ca
# 233    151                                    Mauritania     MRT  .mr
# 234    208                                      Suriname     SUR  .sr
# 235    108                                       Iceland     ISL  .is
# 236     12                                     Australia     AUS  .au
# 237    160                                       Namibia     NAM  .na
# 238     79                                 French Guiana     GUF  .gf
# 239    147                                      Mongolia     MNG  .mn
# 240     65                                Western Sahara     ESH  .eh
# 241    181                                      Pitcairn     PCN  .pn
# 242     71                              Falkland Islands     FLK  .fk
# 243    202                        Svalbard and Jan Mayen     SJM  .sj
# 244     83                                     Greenland     GRL  .gl
# 245    216                   French Southern Territories     ATF  .tf
# 246     89  South Georgia and the South Sandwich Islands     SGS  .gs
# 247     95             Heard Island and McDonald Islands     HMD  .hm
# 248     33                                 Bouvet Island     BVT  .bv
# 249      8                                    Antarctica     ATA  .aq
# 250    232          United States Minor Outlying Islands     UMI  .um
#
#     continent            capital         area  population       density  \
# 0          EU             Monaco         1.95       32965  16905.128205
# 1          AS          Singapore       692.70     4701069   6786.587267
# 2          AS          Hong Kong      1092.00     6898686   6317.478022
# 3          EU          Gibraltar         6.50       27884   4289.846154
# 4          EU       Vatican City         0.44         921   2093.181818
# 5          NM        Philipsburg        21.00       37429   1782.333333
# 6          AS              Macao       254.00      449198   1768.496063
# 7          AS               Male       300.00      395650   1318.833333
# 8          EU           Valletta       316.00      403000   1275.316456
# 9          NM           Hamilton        53.00       65365   1233.301887
# 10         AS             Manama       665.00      738004   1109.780451
# 11         AS              Dhaka    144000.00   156118464   1084.156000
# 12         EU      St Peter Port        78.00       65228    836.256410
# 13         EU       Saint Helier       116.00       90812    782.862069
# 14         NM            Marigot        53.00       35925    677.830189
# 15         NM         Bridgetown       431.00      285653    662.767981
# 16         AS     East Jerusalem      5970.00     3800000    636.515913
# 17         AS             Taipei     35980.00    22894384    636.308616
# 18         AF         Port Louis      2040.00     1294104    634.364706
# 19         EU         San Marino        61.20       31477    514.330065
# 20         AS              Seoul     98480.00    48422644    491.700284
# 21         OC              Yaren        21.00       10065    479.285714
# 22         NM           San Juan      9104.00     3916632    430.210018
# 23         AF          Mamoudzou       374.00      159042    425.245989
# 24         AF             Kigali     26338.00    11055976    419.772800
# 25         OC           Funafuti        26.00       10472    402.769231
# 26         NM           Gustavia        21.00        8450    402.380952
# 27         EU          Amsterdam     41526.00    16645000    400.833213
# 28         AS             Beirut     10400.00     4125247    396.658365
# 29         NM     Fort-de-France      1100.00      432900    393.545455
# ..        ...                ...          ...         ...           ...
# 221        SM              Sucre   1098580.00     9947418      9.054796
# 222        AF        Brazzaville    342000.00     3039126      8.886333
# 223        OC              Alofi       260.00        2166      8.330769
# 224        EU             Moscow  17100000.00   140702000      8.228187
# 225        AF          N'Djamena   1284000.00    10543464      8.211421
# 226        AF             Bangui    622984.00     4844927      7.776969
# 227        AF         Libreville    267667.00     1545255      5.773050
# 228        AS             Astana   2717300.00    15340000      5.645310
# 229        AF            Tripoli   1759540.00     6461454      3.672240
# 230        SM         Georgetown    214970.00      748486      3.481816
# 231        AF           Gaborone    600370.00     2029307      3.380094
# 232        NM             Ottawa   9984670.00    33679000      3.373071
# 233        AF         Nouakchott   1030700.00     3205060      3.109595
# 234        SM         Paramaribo    163270.00      492829      3.018491
# 235        EU          Reykjavik    103000.00      308910      2.999126
# 236        OC           Canberra   7686850.00    21515754      2.799034
# 237        AF           Windhoek    825418.00     2128471      2.578658
# 238        SM            Cayenne     91000.00      195506      2.148418
# 239        AS         Ulan Bator   1565000.00     3086918      1.972472
# 240        AF           El-Aaiun    266000.00      273008      1.026346
# 241        OC          Adamstown        47.00          46      0.978723
# 242        SM            Stanley     12173.00        2638      0.216709
# 243        EU       Longyearbyen     62049.00        2550      0.041097
# 244        NM               Nuuk   2166086.00       56375      0.026026
# 245        AN  Port-aux-Francais      7829.00         140      0.017882
# 246        AN          Grytviken      3903.00          30      0.007686
# 247        AN                NaN       412.00           0      0.000000
# 248        AN                NaN        49.00           0      0.000000
# 249        AN                NaN  14000000.00           0      0.000000
# 250        OC                NaN         0.00           0           NaN
#
#      specific area
# 0         0.000059
# 1         0.000147
# 2         0.000158
# 3         0.000233
# 4         0.000478
# 5         0.000561
# 6         0.000565
# 7         0.000758
# 8         0.000784
# 9         0.000811
# 10        0.000901
# 11        0.000922
# 12        0.001196
# 13        0.001277
# 14        0.001475
# 15        0.001509
# 16        0.001571
# 17        0.001572
# 18        0.001576
# 19        0.001944
# 20        0.002034
# 21        0.002086
# 22        0.002324
# 23        0.002352
# 24        0.002382
# 25        0.002483
# 26        0.002485
# 27        0.002495
# 28        0.002521
# 29        0.002541
# ..             ...
# 221       0.110439
# 222       0.112532
# 223       0.120037
# 224       0.121533
# 225       0.121782
# 226       0.128585
# 227       0.173219
# 228       0.177138
# 229       0.272313
# 230       0.287206
# 231       0.295850
# 232       0.296466
# 233       0.321585
# 234       0.331291
# 235       0.333430
# 236       0.357266
# 237       0.387799
# 238       0.465459
# 239       0.506978
# 240       0.974330
# 241       1.021739
# 242       4.614481
# 243      24.332941
# 244      38.422812
# 245      55.921429
# 246     130.100000
# 247            inf
# 248            inf
# 249            inf
# 250            NaN
#
# [251 rows x 10 columns]

# %% [markdown]
# ### Boolean masks
#
# Such computations can also be used to calculate boolean values.
# For instance, let's compute which countries are in _Europe_.
# We assign it to variable `countries_in_EU` for later use.

# %%
countries_in_EU = country_data['continent'] == 'EU'
countries_in_EU
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16      True
# 17     False
# 18     False
# 19      True
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230     True
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236     True
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Name: continent, Length: 251, dtype: bool

# %% [markdown]
# This may not seem very useful, but wait and see.
#
# Such a column of boolean values is also called a **boolean mask**.
# It can be used to select rows,
# as explained next.

# %% [markdown]
# ### Exercise <span class="exercise">8.c</span>
#
# Compute a boolean mask that is `True` for those rows that have `'Kingston'` as _capital_,
# and assign it to `capital_Kingston` for later use
# (there, you can also check that the boolean mask was computed correctly).

# %%
#// BEGIN_TODO [EDA_8c] Boolean mask for capital Kingston (1 point)

capital_Kingston = country_data['capital'] == 'Kingston'

#// END_TODO [EDA_8c]

capital_Kingston
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Name: capital, Length: 251, dtype: bool

# %% [markdown]
# ### Exercise <span class="exercise">8.d</span>
#
# Compute a boolean mask that is `True` for those rows that have a _population_
# larger than 100 million.
# Assign it to the variable `large_population`.

# %%
#// BEGIN_TODO [EDA_8d] Boolean mask for population larger than 100 million (1 point)

large_population = country_data['population'] > 100000000

#// END_TODO [EDA_8d]

large_population
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233     True
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Name: population, Length: 251, dtype: bool

# %% [markdown]
# ## <span class="section">9.</span> Selecting rows by boolean masks
#
# A **boolean mask** can be used to select those rows
# for which the mask contains the value `True`.
# This is done by using the boolean mask as index of the data frame.
#
# So, let's find those countries in _Europe_:

# %%
country_data[countries_in_EU]
# Out:
#                        name alpha_3  tld continent           capital  \
# 0                   Andorra     AND  .ad        EU  Andorra la Vella
# 5                   Albania     ALB  .al        EU            Tirana
# 11                  Austria     AUT  .at        EU            Vienna
# 14            Aland Islands     ALA  .ax        EU         Mariehamn
# 16   Bosnia and Herzegovina     BIH  .ba        EU          Sarajevo
# 19                  Belgium     BEL  .be        EU          Brussels
# 21                 Bulgaria     BGR  .bg        EU             Sofia
# 35                  Belarus     BLR  .by        EU             Minsk
# 42              Switzerland     CHE  .ch        EU              Bern
# 54                   Cyprus     CYP  .cy        EU           Nicosia
# 55                  Czechia     CZE  .cz        EU            Prague
# 56                  Germany     DEU  .de        EU            Berlin
# 58                  Denmark     DNK  .dk        EU        Copenhagen
# 63                  Estonia     EST  .ee        EU           Tallinn
# 67                    Spain     ESP  .es        EU            Madrid
# 69                  Finland     FIN  .fi        EU          Helsinki
# 73            Faroe Islands     FRO  .fo        EU          Torshavn
# 74                   France     FRA  .fr        EU             Paris
# 76           United Kingdom     GBR  .uk        EU            London
# 80                 Guernsey     GGY  .gg        EU     St Peter Port
# 82                Gibraltar     GIB  .gi        EU         Gibraltar
# 88                   Greece     GRC  .gr        EU            Athens
# 97                  Croatia     HRV  .hr        EU            Zagreb
# 99                  Hungary     HUN  .hu        EU          Budapest
# 101                 Ireland     IRL  .ie        EU            Dublin
# 103             Isle of Man     IMN  .im        EU           Douglas
# 108                 Iceland     ISL  .is        EU         Reykjavik
# 109                   Italy     ITA  .it        EU              Rome
# 110                  Jersey     JEY  .je        EU      Saint Helier
# 122                  Kosovo     XKX  NaN        EU          Pristina
# 129           Liechtenstein     LIE  .li        EU             Vaduz
# 133               Lithuania     LTU  .lt        EU           Vilnius
# 134              Luxembourg     LUX  .lu        EU        Luxembourg
# 135                  Latvia     LVA  .lv        EU              Riga
# 138                  Monaco     MCO  .mc        EU            Monaco
# 139                 Moldova     MDA  .md        EU          Chisinau
# 140              Montenegro     MNE  .me        EU         Podgorica
# 144               Macedonia     MKD  .mk        EU            Skopje
# 153                   Malta     MLT  .mt        EU          Valletta
# 166             Netherlands     NLD  .nl        EU         Amsterdam
# 167                  Norway     NOR  .no        EU              Oslo
# 179                  Poland     POL  .pl        EU            Warsaw
# 184                Portugal     PRT  .pt        EU            Lisbon
# 189                 Romania     ROU  .ro        EU         Bucharest
# 190                  Serbia     SRB  .rs        EU          Belgrade
# 191                  Russia     RUS  .ru        EU            Moscow
# 198                  Sweden     SWE  .se        EU         Stockholm
# 201                Slovenia     SVN  .si        EU         Ljubljana
# 202  Svalbard and Jan Mayen     SJM  .sj        EU      Longyearbyen
# 203                Slovakia     SVK  .sk        EU        Bratislava
# 205              San Marino     SMR  .sm        EU        San Marino
# 230                 Ukraine     UKR  .ua        EU              Kiev
# 236                 Vatican     VAT  .va        EU      Vatican City
#
#             area  population       density  specific area
# 0         468.00       84000    179.487179       0.005571
# 5       28748.00     2986952    103.901211       0.009625
# 11      83858.00     8205000     97.843974       0.010220
# 14       1580.00       26711     16.905696       0.059152
# 16      51129.00     4590000     89.772927       0.011139
# 19      30510.00    10403000    340.970174       0.002933
# 21     110910.00     7148785     64.455730       0.015515
# 35     207600.00     9685000     46.652216       0.021435
# 42      41290.00     7581000    183.603778       0.005447
# 54       9250.00     1102677    119.208324       0.008389
# 55      78866.00    10476000    132.832906       0.007528
# 56     357021.00    81802257    229.124497       0.004364
# 58      43094.00     5484000    127.256695       0.007858
# 63      45226.00     1291170     28.549286       0.035027
# 67     504782.00    46505963     92.130787       0.010854
# 69     337030.00     5244000     15.559446       0.064270
# 73       1399.00       48228     34.473195       0.029008
# 74     547030.00    64768389    118.400068       0.008446
# 76     244820.00    62348447    254.670562       0.003927
# 80         78.00       65228    836.256410       0.001196
# 82          6.50       27884   4289.846154       0.000233
# 88     131940.00    11000000     83.371229       0.011995
# 97      56542.00     4284889     75.782410       0.013196
# 99      93030.00     9982000    107.298721       0.009320
# 101     70280.00     4622917     65.778557       0.015203
# 103       572.00       75049    131.204545       0.007622
# 108    103000.00      308910      2.999126       0.333430
# 109    301230.00    60340328    200.313143       0.004992
# 110       116.00       90812    782.862069       0.001277
# 122     10908.00     1800000    165.016502       0.006060
# 129       160.00       35000    218.750000       0.004571
# 133     65200.00     2944459     45.160414       0.022143
# 134      2586.00      497538    192.396752       0.005198
# 135     64589.00     2217969     34.339733       0.029121
# 138         1.95       32965  16905.128205       0.000059
# 139     33843.00     4324000    127.766451       0.007827
# 140     14026.00      666730     47.535292       0.021037
# 144     25333.00     2062294     81.407413       0.012284
# 153       316.00      403000   1275.316456       0.000784
# 166     41526.00    16645000    400.833213       0.002495
# 167    324220.00     5009150     15.449849       0.064726
# 179    312685.00    38500000    123.127109       0.008122
# 184     92391.00    10676000    115.552381       0.008654
# 189    237500.00    21959278     92.460118       0.010815
# 190     88361.00     7344847     83.123177       0.012030
# 191  17100000.00   140702000      8.228187       0.121533
# 198    449964.00     9828655     21.843203       0.045781
# 201     20273.00     2007000     98.998668       0.010101
# 202     62049.00        2550      0.041097      24.332941
# 203     48845.00     5455000    111.679803       0.008954
# 205        61.20       31477    514.330065       0.001944
# 230    603700.00    45415596     75.228749       0.013293
# 236         0.44         921   2093.181818       0.000478

# %% [markdown]
# And here is the data for the _Netherlands_,
# knowing that is has _top-level domain_ `.nl`:

# %%
country_data[country_data['tld'] == '.nl']
# Out:
#             name alpha_3  tld continent    capital     area  population  \
# 166  Netherlands     NLD  .nl        EU  Amsterdam  41526.0    16645000
#
#         density  specific area
# 166  400.833213       0.002495

# %% [markdown]
# ### Boolean mask for missing values
#
# The `Series` function **`isnull()`** can be used to create a **boolean mask
# for missing values** (these are also known as **not available** (na) or **null values**).
#
# Which countries don't have a _top-level domain_:

# %%
country_data[country_data['tld'].isnull()]
# Out:
#             name alpha_3  tld continent   capital      area  population  \
# 122       Kosovo     XKX  NaN        EU  Pristina   10908.0     1800000
# 197  South Sudan     SSD  NaN        AF      Juba  644329.0     8260490
#
#         density  specific area
# 122  165.016502       0.006060
# 197   12.820298       0.078001

# %% [markdown]
# ### Combining boolean masks
#
# Boolean masks can be combined into more complex boolean conditions using the following operators:
#
# * **`&`** for 'and'
# * **`|`** for 'or'
# * **`~`** for 'not'
#
# These bind stronger than comparison operators
# (use parenthesis to evaluate comparisons first; see next example).

# %% [markdown]
# Let's show data for contries with a _population_ less than one million and
# an _area_ more than one hundred thousand square kilometer:

# %%
country_data[(country_data['population'] < 1000000) & (country_data['area'] > 100000)]
# Out:
#                name alpha_3  tld continent     capital        area  \
# 8        Antarctica     ATA  .aq        AN         NaN  14000000.0
# 65   Western Sahara     ESH  .eh        AF    El-Aaiun    266000.0
# 83        Greenland     GRL  .gl        NM        Nuuk   2166086.0
# 93           Guyana     GUY  .gy        SM  Georgetown    214970.0
# 108         Iceland     ISL  .is        EU   Reykjavik    103000.0
# 208        Suriname     SUR  .sr        SM  Paramaribo    163270.0
#
#      population   density  specific area
# 8             0  0.000000            inf
# 65       273008  1.026346       0.974330
# 83        56375  0.026026      38.422812
# 93       748486  3.481816       0.287206
# 108      308910  2.999126       0.333430
# 208      492829  3.018491       0.331291

# %% [markdown]
# ### Exercise <span class="exercise">9.a</span>
#
# Show the data for countries whose _population_ exceeds 100 million,
# by using the boolean mask `large_population` computed earlier:

# %%
#// BEGIN_TODO [EDA_9a] Show data for countries with large population (1 point)

country_data[large_population]

#// END_TODO [EDA_9a]
# Out:
#               name alpha_3  tld continent      capital        area  \
# 18      Bangladesh     BGD  .bd        AS        Dhaka    144000.0
# 30          Brazil     BRA  .br        SM     Brasilia   8511965.0
# 47           China     CHN  .cn        AS      Beijing   9596960.0
# 100      Indonesia     IDN  .id        AS      Jakarta   1919440.0
# 104          India     IND  .in        AS    New Delhi   3287590.0
# 113          Japan     JPN  .jp        AS        Tokyo    377835.0
# 157         Mexico     MEX  .mx        NM  Mexico City   1972550.0
# 164        Nigeria     NGA  .ng        AF        Abuja    923768.0
# 178       Pakistan     PAK  .pk        AS    Islamabad    803940.0
# 191         Russia     RUS  .ru        EU       Moscow  17100000.0
# 233  United States     USA  .us        NM   Washington   9629091.0
#
#      population      density  specific area
# 18    156118464  1084.156000       0.000922
# 30    201103330    23.625958       0.042326
# 47   1330044000   138.590137       0.007216
# 100   242968342   126.582931       0.007900
# 104  1173108018   356.829172       0.002802
# 113   127288000   336.887795       0.002968
# 157   112468855    57.016986       0.017539
# 164   154000000   166.708524       0.005998
# 178   184404791   229.376310       0.004360
# 191   140702000     8.228187       0.121533
# 233   310232863    32.218292       0.031038

# %% [markdown]
# ### Exercise <span class="exercise">9.b</span>
#
# Show the data for countries with _capital_ `'Kingston'`,
# using the boolean mask `capital_Kingston` computed earlier:

# %%
#// BEGIN_TODO [EDA_9b] Show data for countries with capital Kingston (1 point)

country_data[capital_Kingston]

#// END_TODO [EDA_9b]
# Out:
#                name alpha_3  tld continent   capital     area  population  \
# 111         Jamaica     JAM  .jm        NM  Kingston  10991.0     2847232
# 163  Norfolk Island     NFK  .nf        OC  Kingston     34.6        1828
#
#         density  specific area
# 111  259.051224       0.003860
# 163   52.832370       0.018928

# %% [markdown]
# ### Exercise <span class="exercise">9.c</span>
#
# Show the data for countries for which the _capital_ is missing in the data set.
# (Hint: Use `isnull()` to construct an appropriate _boolean mask_.)

# %%
#// BEGIN_TODO [EDA_9c] Show data for countries whose capital is missing (1 point)

country_data[country_data['capital'].isnull()]

#// END_TODO [EDA_9c]
# Out:
#                                      name alpha_3  tld continent capital  \
# 8                              Antarctica     ATA  .aq        AN     NaN
# 29     Bonaire, Saint Eustatius and Saba      BES  .bq        NM     NaN
# 33                          Bouvet Island     BVT  .bv        AN     NaN
# 95      Heard Island and McDonald Islands     HMD  .hm        AN     NaN
# 220                               Tokelau     TKL  .tk        OC     NaN
# 232  United States Minor Outlying Islands     UMI  .um        OC     NaN
#
#            area  population     density  specific area
# 8    14000000.0           0    0.000000            inf
# 29        328.0       18012   54.914634       0.018210
# 33         49.0           0    0.000000            inf
# 95        412.0           0    0.000000            inf
# 220        10.0        1466  146.600000       0.006821
# 232         0.0           0         NaN            NaN

# %% [markdown]
# ### Exercise <span class="exercise">9.d</span>
#
# Show data for those countries in _Europe_ that have a _population_ between ten and twenty million.
# Hint: First compute three separate boolean masks:
#
# * `countries_in_EU` for 'in Europe'
# * `pop_more_10M` for 'population at least ten million'
# * `pop_less_20M` for 'population at most twenty million'
#
# then combine them into one boolean mask using `&`.

# %%
#// BEGIN_TODO [EDA_9d] Population between ten and twenty million (1 point)

pop_more_10M = country_data['population'] >= 10000000
pop_less_20M = country_data['population'] <= 20000000
country_data[countries_in_EU][(pop_more_10M)&(pop_less_20M)]

#// END_TODO [EDA_9d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#             name alpha_3  tld continent    capital      area  population  \
# 19       Belgium     BEL  .be        EU   Brussels   30510.0    10403000
# 55       Czechia     CZE  .cz        EU     Prague   78866.0    10476000
# 88        Greece     GRC  .gr        EU     Athens  131940.0    11000000
# 166  Netherlands     NLD  .nl        EU  Amsterdam   41526.0    16645000
# 184     Portugal     PRT  .pt        EU     Lisbon   92391.0    10676000
#
#         density  specific area
# 19   340.970174       0.002933
# 55   132.832906       0.007528
# 88    83.371229       0.011995
# 166  400.833213       0.002495
# 184  115.552381       0.008654

# %% [markdown]
# ## <span class="section">10.</span> Grouping rows in a `DataFrame`

# %% [markdown]
# By sorting a data frame,
# you can bring items with the same value together.
# But this is not good enough to gather statistics
# about groups of equal values.
#
# Take for instance the country data.
# What about total _population_ and _area_ per _continent_?
#
# That is where **grouping** comes in.
# First, we create a so-called `GroupBy` object
# from the data frame,
# using the function **`groupby()`**
# with the column label(s) to group by as argument.
#
# This is how you group the country data by _continent_,
# and assign the `GroupBy` object to variable `grouped`.

# %%
grouped = country_data.groupby('continent')

# %% [markdown]
# The **`groups`** attribute of the `GroupBy` object
# shows for each continent which rows concern that continent:

# %%
grouped.groups
# Out:
# {'AF': Int64Index([  7,  20,  23,  24,  34,  39,  40,  41,  43,  46,  51,  57,  61,
#               64,  65,  66,  68,  75,  81,  84,  85,  87,  92, 114, 118, 131,
#              132, 136, 137, 142, 145, 151, 154, 156, 159, 160, 162, 164, 188,
#              192, 195, 196, 197, 200, 204, 206, 207, 209, 213, 215, 217, 223,
#              229, 231, 246, 247, 248, 249],
#             dtype='int64'),
#  'AN': Int64Index([8, 33, 89, 95, 216], dtype='int64'),
#  'AS': Int64Index([  1,   2,   6,  15,  18,  22,  27,  32,  38,  47,  53,  78,  94,
#              100, 102, 104, 105, 106, 107, 112, 113, 115, 116, 120, 121, 123,
#              125, 126, 127, 130, 146, 147, 148, 155, 158, 168, 172, 177, 178,
#              183, 187, 193, 199, 212, 218, 219, 222, 225, 228, 235, 241, 245],
#             dtype='int64'),
#  'EU': Int64Index([  0,   5,  11,  14,  16,  19,  21,  35,  42,  54,  55,  56,  58,
#               63,  67,  69,  73,  74,  76,  80,  82,  88,  97,  99, 101, 103,
#              108, 109, 110, 122, 129, 133, 134, 135, 138, 139, 140, 144, 153,
#              166, 167, 179, 184, 189, 190, 191, 198, 201, 202, 203, 205, 230,
#              236],
#             dtype='int64'),
#  'NM': Int64Index([  3,   4,  13,  17,  25,  26,  29,  31,  36,  37,  49,  50,  52,
#               59,  60,  77,  83,  86,  90,  96,  98, 111, 119, 124, 128, 141,
#              150, 152, 157, 165, 173, 180, 182, 210, 211, 214, 226, 233, 237,
#              239, 240, 250],
#             dtype='int64'),
#  'OC': Int64Index([ 10,  12,  44,  70,  72,  91, 117, 143, 149, 161, 163, 169, 170,
#              171, 175, 176, 181, 185, 194, 220, 221, 224, 227, 232, 242, 243,
#              244],
#             dtype='int64'),
#  'SM': Int64Index([9, 28, 30, 45, 48, 62, 71, 79, 93, 174, 186, 208, 234, 238], dtype='int64')}

# %% [markdown]
# > Note that Australia and New Zealand are apparently put under Oceania,
# > since there is no separate continent `AU`.

# %% [markdown]
# The `GroupBy` object can be treated like a `DataFrame` in a number of ways.
#
# For instance, this is how you get the summary statistics for _area_ per _continent_:

# %%
grouped['area'].describe()
# Out:
#            count          mean           std       min        25%       50%  \
# continent
# AF          58.0  5.234534e+05  5.956923e+05    374.00   31796.25  270933.5
# AN           5.0  2.802439e+06  6.259628e+06     49.00     412.00    3903.0
# AS          52.0  6.077544e+05  1.454325e+06     14.00   20032.50  143550.0
# EU          53.0  4.354706e+05  2.338187e+06      0.44    9250.00   51129.0
# NM          42.0  5.836313e+05  2.134253e+06     21.00     278.50     857.0
# OC          27.0  3.156854e+05  1.476550e+06      0.00     190.15     549.0
# SM          14.0  1.272751e+06  2.207496e+06  12173.00  185907.50  581850.0
#
#                  75%         max
# continent
# AF          819461.0   2381740.0
# AN            7829.0  14000000.0
# AS          494575.0   9596960.0
# EU          131940.0  17100000.0
# NM           43485.0   9984670.0
# OC           13603.5   7686850.0
# SM         1128827.5   8511965.0

# %% [markdown]
# And this is how you get total _population_ and _area_ per _continent_:

# %%
grouped[['population', 'area']].sum()
# Out:
#            population         area
# continent
# AF         1016879730  30360296.00
# AN                170  14012193.00
# AS         4130586341  31603228.70
# EU          739141025  23079944.09
# NM          540105043  24512514.00
# OC           36066049   8523505.90
# SM          400143568  17818508.00

# %% [markdown]
# ### Exercise <span class="exercise">10.a</span>
#
# Show the summary statistics for _population_ per _continent_ (you can reuse the variable `grouped` introduced before).

# %%
#// BEGIN_TODO [EDA_10a] Summary statistics for population per continent (1 point)

grouped['population'].describe()

#// END_TODO [EDA_10a]
# Out:
#            count          mean           std     min         25%         50%  \
# continent
# AF          58.0  1.753241e+07  2.663389e+07  7460.0  1674830.00   9987785.0
# AN           5.0  3.400000e+01  6.066300e+01     0.0        0.00         0.0
# AS          52.0  7.943435e+07  2.424824e+08   628.0  3621729.50  11378596.0
# EU          53.0  1.394606e+07  2.615535e+07   921.0   403000.00   4590000.0
# NM          42.0  1.285964e+07  5.031131e+07  7012.0    52444.25    223287.5
# OC          27.0  1.335780e+06  4.262102e+06     0.0    13248.50     92533.0
# SM          14.0  2.858168e+07  5.209916e+07  2638.0  1430614.50  12369013.0
#
#                    75%           max
# continent
# AF         20617635.75  1.540000e+08
# AN               30.00  1.400000e+02
# AS         34359364.75  1.330044e+09
# EU         10403000.00  1.407020e+08
# NM          4366323.00  3.102329e+08
# OC           246018.50  2.151575e+07
# SM         29236059.25  2.011033e+08

# %% [markdown]
# ### Exercise <span class="exercise">10.b</span>
#
# Show _maximum_ _density_ per _continent_ returning the result as a `Series` object:

# %%
#// BEGIN_TODO [EDA_10b] Maximum density per continent (1 point)

grouped['density'].max()

#// END_TODO [EDA_10b]
# Out:
# continent
# AF      634.364706
# AN        0.017882
# AS     6786.587267
# EU    16905.128205
# NM     1782.333333
# OC      479.285714
# SM       52.160418
# Name: density, dtype: float64

# %% [markdown]
# ## <span class="section">11.</span> Deleting rows or columns from a `DataFrame`
#
# To delete one or more rows or columns from `DataFrame df`
# use the data frame function **`df.drop()`**.
#
# * **`df.drop(row)`**
# * **`df.drop(list_of_rows)`**
# * **`df.drop(column, axis=1)`**
# * **`df.drop(list_columns, axis=1)`**
#
# This returns a _new data frame_, with the specified rows or columns removed.
#
# The parameter `axis` indicates along which axis to drop.
# The default is `axis=0`, to drop rows.
#
# For example, given the following data frame

# %%
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': ['one', 'two', 'three', 'four'], 'C': [False, True, False, True]})
df
# Out:
#    A      B      C
# 0  1    one  False
# 1  2    two   True
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# You can drop the row with index label 1 (i.e. the second row):

# %%
df.drop(1)
# Out:
#    A      B      C
# 0  1    one  False
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# You can drop the column with label 'C':

# %%
df.drop('C', axis=1)
# Out:
#    A      B
# 0  1    one
# 1  2    two
# 2  3  three
# 3  4   four

# %% [markdown]
# You can also **drop rows based on a condition** using `drop()`,
# by cleverly combining
#
# * selection with a boolean mask and
# * the `index` attribute:
#
# ```python
# df.drop(df[boolean_mask].index)
# ```
#
# For example, you can drop countries in Europe from the `country_data` data frame:

# %%
country_data.drop(country_data[countries_in_EU].index)
# Out:
#                                      name alpha_3  tld continent  \
# 1                    United Arab Emirates     ARE  .ae        AS
# 2                             Afghanistan     AFG  .af        AS
# 3                     Antigua and Barbuda     ATG  .ag        NM
# 4                                Anguilla     AIA  .ai        NM
# 6                                 Armenia     ARM  .am        AS
# 7                                  Angola     AGO  .ao        AF
# 8                              Antarctica     ATA  .aq        AN
# 9                               Argentina     ARG  .ar        SM
# 10                         American Samoa     ASM  .as        OC
# 12                              Australia     AUS  .au        OC
# 13                                  Aruba     ABW  .aw        NM
# 15                             Azerbaijan     AZE  .az        AS
# 17                               Barbados     BRB  .bb        NM
# 18                             Bangladesh     BGD  .bd        AS
# 20                           Burkina Faso     BFA  .bf        AF
# 22                                Bahrain     BHR  .bh        AS
# 23                                Burundi     BDI  .bi        AF
# 24                                  Benin     BEN  .bj        AF
# 25                       Saint Barthelemy     BLM  .gp        NM
# 26                                Bermuda     BMU  .bm        NM
# 27                                 Brunei     BRN  .bn        AS
# 28                                Bolivia     BOL  .bo        SM
# 29     Bonaire, Saint Eustatius and Saba      BES  .bq        NM
# 30                                 Brazil     BRA  .br        SM
# 31                                Bahamas     BHS  .bs        NM
# 32                                 Bhutan     BTN  .bt        AS
# 33                          Bouvet Island     BVT  .bv        AN
# 34                               Botswana     BWA  .bw        AF
# 36                                 Belize     BLZ  .bz        NM
# 37                                 Canada     CAN  .ca        NM
# ..                                    ...     ...  ...       ...
# 219                            Tajikistan     TJK  .tj        AS
# 220                               Tokelau     TKL  .tk        OC
# 221                            East Timor     TLS  .tl        OC
# 222                          Turkmenistan     TKM  .tm        AS
# 223                               Tunisia     TUN  .tn        AF
# 224                                 Tonga     TON  .to        OC
# 225                                Turkey     TUR  .tr        AS
# 226                   Trinidad and Tobago     TTO  .tt        NM
# 227                                Tuvalu     TUV  .tv        OC
# 228                                Taiwan     TWN  .tw        AS
# 229                              Tanzania     TZA  .tz        AF
# 231                                Uganda     UGA  .ug        AF
# 232  United States Minor Outlying Islands     UMI  .um        OC
# 233                         United States     USA  .us        NM
# 234                               Uruguay     URY  .uy        SM
# 235                            Uzbekistan     UZB  .uz        AS
# 237      Saint Vincent and the Grenadines     VCT  .vc        NM
# 238                             Venezuela     VEN  .ve        SM
# 239                British Virgin Islands     VGB  .vg        NM
# 240                   U.S. Virgin Islands     VIR  .vi        NM
# 241                               Vietnam     VNM  .vn        AS
# 242                               Vanuatu     VUT  .vu        OC
# 243                     Wallis and Futuna     WLF  .wf        OC
# 244                                 Samoa     WSM  .ws        OC
# 245                                 Yemen     YEM  .ye        AS
# 246                               Mayotte     MYT  .yt        AF
# 247                          South Africa     ZAF  .za        AF
# 248                                Zambia     ZMB  .zm        AF
# 249                              Zimbabwe     ZWE  .zw        AF
# 250                  Netherlands Antilles     ANT  .an        NM
#
#                  capital        area  population      density  specific area
# 1              Abu Dhabi     82880.0     4975593    60.033699       0.016657
# 2                  Kabul    647500.0    29121286    44.974959       0.022235
# 3             St. John's       443.0       86754   195.832957       0.005106
# 4             The Valley       102.0       13254   129.941176       0.007696
# 6                Yerevan     29800.0     2968000    99.597315       0.010040
# 7                 Luanda   1246700.0    13068161    10.482202       0.095400
# 8                    NaN  14000000.0           0     0.000000            inf
# 9           Buenos Aires   2766890.0    41343201    14.942119       0.066925
# 10             Pago Pago       199.0       57881   290.859296       0.003438
# 12              Canberra   7686850.0    21515754     2.799034       0.357266
# 13            Oranjestad       193.0       71566   370.808290       0.002697
# 15                  Baku     86600.0     8303512    95.883510       0.010429
# 17            Bridgetown       431.0      285653   662.767981       0.001509
# 18                 Dhaka    144000.0   156118464  1084.156000       0.000922
# 20           Ouagadougou    274200.0    16241811    59.233446       0.016882
# 22                Manama       665.0      738004  1109.780451       0.000901
# 23             Bujumbura     27830.0     9863117   354.405929       0.002822
# 24            Porto-Novo    112620.0     9056010    80.412094       0.012436
# 25              Gustavia        21.0        8450   402.380952       0.002485
# 26              Hamilton        53.0       65365  1233.301887       0.000811
# 27   Bandar Seri Begawan      5770.0      395027    68.462218       0.014607
# 28                 Sucre   1098580.0     9947418     9.054796       0.110439
# 29                   NaN       328.0       18012    54.914634       0.018210
# 30              Brasilia   8511965.0   201103330    23.625958       0.042326
# 31                Nassau     13940.0      301790    21.649211       0.046191
# 32               Thimphu     47000.0      699847    14.890362       0.067158
# 33                   NaN        49.0           0     0.000000            inf
# 34              Gaborone    600370.0     2029307     3.380094       0.295850
# 36              Belmopan     22966.0      314522    13.695115       0.073019
# 37                Ottawa   9984670.0    33679000     3.373071       0.296466
# ..                   ...         ...         ...          ...            ...
# 219             Dushanbe    143100.0     7487489    52.323473       0.019112
# 220                  NaN        10.0        1466   146.600000       0.006821
# 221                 Dili     15007.0     1154625    76.939095       0.012997
# 222             Ashgabat    488100.0     4940916    10.122754       0.098787
# 223                Tunis    163610.0    10589025    64.721136       0.015451
# 224           Nuku'alofa       748.0      122580   163.877005       0.006102
# 225               Ankara    780580.0    77804122    99.674757       0.010033
# 226        Port of Spain      5128.0     1228691   239.604329       0.004174
# 227             Funafuti        26.0       10472   402.769231       0.002483
# 228               Taipei     35980.0    22894384   636.308616       0.001572
# 229               Dodoma    945087.0    41892895    44.327025       0.022560
# 231              Kampala    236040.0    33398682   141.495857       0.007067
# 232                  NaN         0.0           0          NaN            NaN
# 233           Washington   9629091.0   310232863    32.218292       0.031038
# 234           Montevideo    176220.0     3477000    19.731018       0.050682
# 235             Tashkent    447400.0    27865738    62.283724       0.016056
# 237            Kingstown       389.0      104217   267.910026       0.003733
# 238              Caracas    912050.0    27223228    29.848394       0.033503
# 239            Road Town       153.0       21730   142.026144       0.007041
# 240     Charlotte Amalie       352.0      108708   308.829545       0.003238
# 241                Hanoi    329560.0    89571130   271.790053       0.003679
# 242            Port Vila     12200.0      221552    18.160000       0.055066
# 243             Mata Utu       274.0       16025    58.485401       0.017098
# 244                 Apia      2944.0      192001    65.217731       0.015333
# 245                Sanaa    527970.0    23495361    44.501318       0.022471
# 246            Mamoudzou       374.0      159042   425.245989       0.002352
# 247             Pretoria   1219912.0    49000000    40.166832       0.024896
# 248               Lusaka    752614.0    13460305    17.884739       0.055914
# 249               Harare    390580.0    13061000    33.440012       0.029904
# 250           Willemstad       960.0      300000   312.500000       0.003200
#
# [198 rows x 9 columns]

# %% [markdown]
# ## <span class="section">12.</span> Persisting the modifications
#
# The data frame functions that we have discussed so far (`sort_values(), head(), drop()`) return a _new_ data frame, just like the `copy()` method we have seen before. To store the results of any modifications to a data frame we can assign the result to a new variable and then work on that variable.
#
# For example, the `drop()` function will return a new data frame:

# %%
df_drop = df.drop('C', axis=1)
df_drop
# Out:
#    A      B
# 0  1    one
# 1  2    two
# 2  3  three
# 3  4   four

# %% [markdown]
# The original data frame `df` is not affected by the dropping:

# %%
df
# Out:
#    A      B      C
# 0  1    one  False
# 1  2    two   True
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# Moreover, any modifications to `df_drop` will not affect `df`:

# %%
df_drop.loc[1, 'B'] = 'EIGHT'
df_drop
# Out:
#    A      B
# 0  1    one
# 1  2  EIGHT
# 2  3  three
# 3  4   four

# %%
df
# Out:
#    A      B      C
# 0  1    one  False
# 1  2    two   True
# 2  3  three  False
# 3  4   four   True

# %% [markdown]
# #### The `inplace` argument
#
# For many data frame methods you can supply the extra argument **`inplace=True`**, to store the modifications in the target data frame. However, this is usually not recommended; it is often better to assign the result to a new variable.

# %%
df.drop([1, 3], inplace=True)  # drop rows with index labels 1 and 3, modifying df in place
df
# Out:
#    A      B      C
# 0  1    one  False
# 2  3  three  False

# %% [markdown]
# ## <span class="section">13.</span> Plotting a `DataFrame`

# %% [markdown]
# Various plots can be made directly from a `DataFrame` or `Series` object.
#
# First, we
#
# * import the underlying plotting libraries **Matplotlib** and **Seaborn**,
# * issue the command **`%matplotlib inline`**
#     to make plots appear inside the notebook,
# * and configure some parameters (see the comments for details).

# %%
# next command ensures that plots appear inside the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()  # set Seaborn defaults
plt.rcParams['figure.figsize'] = 10, 5  # default hor./vert. size of plots, in inches
plt.rcParams['lines.markeredgewidth'] = 1  # to fix issue with seaborn box plots; needed after import seaborn

# %% [markdown]
# > NOTE: This section presents a brief overview of plotting data for a quick exploration. More advanced plotting and annotation methods that are needed for communicating your data analysis with others will be addressed in _Exercises - VIS_.

# %% [markdown]
# The general function to make a plot for a `DataFrame df` is
#
# * **`df.plot(kind='...', ...)`**
#
# where the following kinds of plots are supported.
#
# * **`'line'`** : default
# * **`'area'`** : like `'line'`, but with area below line filled in
# * **`'bar'`** : vertical bar plot, with separated bars
# * **`'barh'`** : horizontal bar plot, with separated bars
# * **`'hist'`** : histogram, with automatic binning; use `bins=n` to set the number of bins to `n`
# * **`'box'`** : vertical box (and whisker) plot, with outliers
# * **`'density'`** : density plot (a kind of continuous histogram)
# * **`'scatter'`** : scatter plot
#
# All of these plots, **except `'scatter`'**, apply to `Series` objects as well.
#
# When used on a `DataFrame` object, all (numeric) columns are plotted,
# and a **legend** is included.
#
# The extra arguments are mostly irrelevant in this lesson;
# the ones that are relevant will be discussed below.
#
# For **box plots** of `DataFrame` objects, there is a special variant:
#
# * **`df.boxplot(column=..., by=...)`** :
#     side-by-side box plots for given column(s), grouped by given column(s)
#
# In this lesson, we will stick to default plotting behavior,
# which is good enough for _personal plots_.
#
# Remember that you can get built-in help with `?`.
# Execute the following cell to get built-in help for the Pandas plotting function
# (most of the details are irrelevant for this lesson):

# %%
df.plot?

# %% [markdown]
# ### Line plot
#
# We begin with a **line plot** of the  _population_ per country.
# Note that in this plot, the x-axis has the row indices.
# Thus, the countries are ordered as in the original data file.

# %%
country_data['population'].plot();

# %% [markdown]
# The semicolon ('**`;`**') on the last line
# suppresses the textual output (which is not relevant for us).
#
# We can plot the _population_ in descending order,
# by using the earlier computed `country_data_sorted_by_pop`:

# %%
country_data_sorted_by_pop['population'].plot();

# %% [markdown]
# ### Area plot
#
# Now, the same plots as **area plot**:

# %%
country_data['population'].plot(kind='area');

# %%
country_data_sorted_by_pop['population'].plot(kind='area');

# %% [markdown]
# ### Dot plot
#
# A **dot plot** is obtained by creating a _line plot_ where the _marker_ is set to dots (**`marker='o'`**) and the lines are hidden (**`linestyle=''`**):

# %%
country_data['population'].plot(marker="o", linestyle='');

# %% [markdown]
# ### Histogram
#
# We plot a **histogram** for the _population_ in _Europe_,
# using the default number of bins.
# First, we select the relevant data,
# reusing the boolean mask `countries_in_EU`
# (this results in a `DataFrame` object,
# because of the double square brackets around `'population'`).

# %%
country_data[countries_in_EU][['population']].plot(kind='hist');

# %% [markdown]
# When plotting a single series of this data frame,
# the histogram will not include a legend
# (now there are single square brackets around `'population'`):

# %%
country_data[countries_in_EU]['population'].plot(kind='hist');

# %% [markdown]
# Next, we plot a **histogram** for this data,
# using 20 bins (`bins=20`), and normalizing the total area to one (`normed=True`):

# %%
country_data[countries_in_EU][['population']].plot(kind='hist', bins=20, normed=True);

# %% [markdown]
# ### Density plot
#
# A **density plot** (a kind of continuous histogram) for the same data:

# %%
country_data[countries_in_EU][['population']].plot(kind='density');

# %% [markdown]
# >NOTE: The contribution of each value is smeared out and integrated.
# > Of course, there are no negative populations.

# %% [markdown]
# ### Box plot
#
# A **box plot** for the _population_
# (note the **outliers**):

# %%
country_data[countries_in_EU][['population']].plot(kind='box');

# %% [markdown]
# A **box plot** for the _population_ **grouped by** _continent_:

# %%
country_data.boxplot(column='population', by='continent');

# %% [markdown]
# > Note: if you receive a `FutureWarning` about `reshape` being deprecated, you can safely ignore it.

# %% [markdown]
# ### Bar plot
#
# A **bar plot** for the _number of countries_ per _continent_
# can be obtained via **grouping**.
# Recall that `grouped` was defined earlier
# to capture the grouping of country data per continent.

# %%
grouped['continent'].count().plot(kind='bar');

# %% [markdown]
# A **bar plot** for total _population_ per _continent_,
# again based on the grouping computed earlier:

# %%
grouped['population'].sum().plot(kind='bar');

# %% [markdown]
# ### Scatter plot
#
# A **scatter plot** that plots _area_ against _population_:

# %%
country_data.plot(kind='scatter', x='area', y='population');

# %% [markdown]
# ### Exercise <span class="exercise">13.a</span>
#
# Show a dot plot of _area_ per country.

# %%
#// BEGIN_TODO [EDA_13a] Dot plot for area per country (1 point)

country_data['area'].plot(marker="o", linestyle='');

#// END_TODO [EDA_13a]

# %% [markdown]
# ### Exercise <span class="exercise">13.b</span>
#
# Show an area plot of the _area_ per country sorted in descending order.
# (Hint: First compute country data sorted in descending order by _area_,
# assigning it to `country_data_sorted_by_area`.
# Don't forget to use `.reset_index()`.)

# %%
#// BEGIN_TODO [EDA_13b] Area plot for area per country (1 point)

country_data_sorted_by_area = country_data.sort_values(by='area', ascending=False).reset_index()
country_data_sorted_by_area['area'].plot(kind='area');

#// END_TODO [EDA_13b]

# %% [markdown]
# ### Exercise <span class="exercise">13.c</span>
#
# Show a histogram with 30 bins for the country _area_ in _Europe_.
# (Hint: Reuse the boolean mask `countries_in_EU` computed earlier.)

# %%
#// BEGIN_TODO [EDA_13c] Histogram for area per country in Europe (1 point)

country_data[countries_in_EU][['area']].plot(kind='hist', bins=30);

#// END_TODO [EDA_13c]

# %% [markdown]
# The resulting histogram is not very informative,
# illustrating the limitation of histograms.
# Here, this is caused by one **outlier**.
#
# ### Exercise <span class="exercise">13.d</span>
#
# Define a boolean mask `countries_in_EU_not_RUS` for countries in _Europe_ without _Russia_.
# (Hint: Reuse the boolean mask `countries_in_EU`.
# The `alpha_3` code of Russia is `RUS`.)

# %%
#// BEGIN_TODO [EDA_13d] Boolean mask for countries in Europe without Russia (1 point)

nietrusland = country_data['alpha_3'] != 'RUS'
countries_in_EU_not_RUS = countries_in_EU & nietrusland

countries_in_EU_not_RUS

#// END_TODO [EDA_13d]
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16      True
# 17     False
# 18     False
# 19      True
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230     True
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236     True
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Length: 251, dtype: bool

# %% [markdown]
# ### Exercise <span class="exercise">13.e</span>
#
# Show a histogram with 30 bins for the country _area_ in _Europe_ without _Russia_.
# (Hint: Reuse the boolean mask `countries_in_EU_not_RUS` computed earlier.)

# %%
#// BEGIN_TODO [EDA_13e] Histogram for area per country in Europe (1 point)


country_data[countries_in_EU_not_RUS][['area']].plot(kind='hist', bins=30);


#// END_TODO [EDA_13e]

# %% [markdown]
# ### Exercise <span class="exercise">13.f</span>
#
# Show a density plot for the country _area_ in _Europe_ without _Russia_.

# %%
#// BEGIN_TODO [EDA_13f] Density plot for area per country in Europe (1 point)

country_data[countries_in_EU_not_RUS][['area']].plot(kind='density');

#// END_TODO [EDA_13f]

# %% [markdown]
# ### Exercise <span class="exercise">13.g</span>
#
# Show a box plot for the country _area_ in _Europe_ without _Russia_:

# %%
#// BEGIN_TODO [EDA_13g] Box plot for area per country in Europe without Russia (1 point)

country_data[countries_in_EU_not_RUS][['area']].plot(kind='box');

#// END_TODO [EDA_13g]

# %% [markdown]
# ### Exercise <span class="exercise">13.h</span>
#
# A box plot for country _area_ grouped by _continent_:

# %%
#// BEGIN_TODO [EDA_13h] Box plots for country area grouped by continent (1 point)

country_data.boxplot(column='area', by='continent');

#// END_TODO [EDA_13h]

# %% [markdown]
# ### Exercise <span class="exercise">13.i</span>
#
# Show a scatter plot that plots _area_ against _population_
# for countries in _Europe_ without _Russia_:

# %%
#// BEGIN_TODO [EDA_13i] Scatter plot for area against population for countries in Europe without Russia (1 point)

country_data[countries_in_EU_not_RUS].plot(kind='scatter', x='area', y='population');

#// END_TODO [EDA_13i]

# %% [markdown]
# # <span class="section">14.</span> Exercise: speed of light
#
# In the 19th century,
# French physicists Fizeau and Foucault independently invented ways to measure the speed of light.
# Foucault's method turned out to be the most accurate one.
# The Foucault method is based on fast rotation mirrors.
# The American physicists Michelson and Newcomb improved Foucault's method.
# The data set `light.csv` contains measurements by Newcomb from 1882.

# %% [markdown]
# ### Exercise <span class="exercise">14.a</span>: Load the data set
#
# Write Python code to load the data set into a Pandas `DataFrame` named `df_light` and show the first 10 rows.

# %%
file_light = './datasets/light.csv'

#// BEGIN_TODO [EDA_14a] Load the data set and show first 10 rows (1 point)

df_light = pd.read_csv(file_light)
df_light.head(10)


#// END_TODO [EDA_14a]
# Out:
#    Value
# 0     28
# 1     26
# 2     33
# 3     24
# 4     34
# 5    -44
# 6     27
# 7     16
# 8     40
# 9     -2

# %% [markdown]
# ### Exercise <span class="exercise">14.b</span>: Summary statistics of raw values
#
# Show the summary statistics for the `df_light` data frame.

# %%
#// BEGIN_TODO [EDA_14b] Summary statistics (1 point)

df_light.describe()

#// END_TODO [EDA_14b]
# Out:
#            Value
# count  66.000000
# mean   26.212121
# std    10.745325
# min   -44.000000
# 25%    24.000000
# 50%    27.000000
# 75%    30.750000
# max    40.000000

# %% [markdown]
# ### Exercise <span class="exercise">14.c</span>: Observation
#
# Looking at the summary statistics, what do you observe? Select one of the answers below and assign your answer as string to the variable `stats_observation`, e.g. `stats_observation = 'a'`.
#
# a) On average, the values are as expected.
#
# b) The mean and the median are equal.
#
# c) It is not clear how these values are related to the speed of light, e.g. there are negative values.
#
# d) The median is in the middle between the min and max and equal to -2.

# %%
#// BEGIN_TODO [EDA_14c] What do you notice? (1 point)

stats_observation = 'c'

#// END_TODO [EDA_14c]

stats_observation
# Out:
# 'c'

# %% [markdown]
# ### Exercise <span class="exercise">14.d</span>: Add column with the decoded speed
#
# It turns out that Newcomb coded the measurements to get smaller numbers in his table. The coding of these measurements was as follows:
#
# > From the original measurements of time (in microseconds) needed by light to travel a distance of 7442 meters,
# > first 24.8 was subtracted,
# > after which the results were multiplied with 1000.
#
# Create a new column labeled `"Speed [km/s]"` in your data set with the measured light speed in km/s.

# %%
#// BEGIN_TODO [EDA_14d] Added column with speed in km/s (1 point)

x = (df_light['Value'] / 1000) + 24.8
y = 7.442 / (x / 1000000)
df_light['Speed [km/s]'] = y 

#// END_TODO [EDA_14d]

# %% [markdown]
# ### Exercise <span class="exercise">14.e</span>: Summary statistics of the decoded speed
#
# Show the summary statistics for the speed of light in km/s.

# %%
#// BEGIN_TODO [EDA_14e] Summary statics of speed (1 point)

df_light['Speed [km/s]'].describe()

#// END_TODO [EDA_14e]
# Out:
# count        66.000000
# mean     299763.868098
# std         129.995513
# min      299597.423510
# 25%      299709.030225
# 50%      299754.299754
# 75%      299790.525298
# max      300613.992567
# Name: Speed [km/s], dtype: float64

# %% [markdown]
# ### Exercise <span class="exercise">14.f</span>: Make a dot plot
#
# Make a dot plot of the speed of light in km/s against the observation number (the observations are ordered by time).

# %%
#// BEGIN_TODO [EDA_14f] Plot data against observation number (1 point)

df_light['Speed [km/s]'].plot(marker="o", linestyle='');

#// END_TODO [EDA_14f]

# %% [markdown]
# ### Exercise <span class="exercise">14.g</span>: Remove suspicious rows
#
# Clean the data by removing any suspicious observations that you found in the previous question and
# recompute the summary statistics of the speed of light in km/s
# without these suspect observations.
#
# Store the modified `DataFrame` under the name `df_light_clean`.
#
# Hint: You are encouraged to add new markdown and code cells between the marker lines to explain the steps you are taking, e.g. what you define as a suspicious observation.

# %%
#// BEGIN_TODO [EDA_14g] Remove suspicious rows (1 point)

tb = df_light['Speed [km/s]'].mean() + df_light['Speed [km/s]'].std() < df_light['Speed [km/s]']
ts = df_light['Speed [km/s]'].mean() - df_light['Speed [km/s]'].std() > df_light['Speed [km/s]']
out=tb|ts
df_light_clean= df_light.drop(df_light[out].index)

# %%
#// END_TODO [EDA_14g]

# %% [markdown]
# ### Exercise <span class="exercise">14.h</span>: Check normality
#
# Use appropriate plots to check whether a normal distribution (bell-shaped curve)
# seems appropriate for the measurements of the speed of light in km/s for the two cases: _original_ data (`df_light`) and _cleaned_ data (`df_light_clean`).
#
# Assign your (boolean) answers to the variables `original_speed_is_normal` and `clean_speed_is_normal`. For example, if you think that the distribution of the speed of light in the _original_ data is normal, then assign `original_speed_is_normal = True`, otherwise if you think that it is not normal, assign `original_speed_is_normal = False`.

# %%
#// BEGIN_TODO [EDA_14h] Normality of distribution of the original and cleaned data (1 point)

df_light['Speed [km/s]'].plot(kind='density');
df_light_clean['Speed [km/s]'].plot(kind='density');

# %%
original_speed_is_normal = True
clean_speed_is_normal = True
#// END_TODO [EDA_14h]

original_speed_is_normal, clean_speed_is_normal
# Out:
# (True, True)

# %% [markdown]
# ### Exercise <span class="exercise">14.i</span>: Compare to current estimate
#
# Find (using external sources) the current estimate for the speed of light in km/s.
# Assign this value (in km/s) to the variable `c`. Does this value seem to be consistent with Newcomb's measurements in the _cleaned_ data?
#
# Compute the **$z$-score** for the current estimate with respect to Newcomb's measurements
# (see lecture slides for details about **$z$-score**). Assign your computed $z$-score to the variable `newcomb_z`.
#
# Also, compute the **relative error percentage** of Newcomb's mean value with respect to the current estimate, i.e.
#
# $$
# \textsf{relative error percentage} = \frac{(\textsf{Newcomb's mean value}) - (\textsf{current estimate})}{\textsf{current estimate}} \times 100 \%
# $$
#
# Assign your computed relative error percentage to the variable `newcomb_rel`.
#
# Hint: You are encouraged to add new markdown and code cells as needed between the marker lines.

# %%
#// BEGIN_TODO [EDA_14i] Compare to current measurements (1 point)

c = 299792.458
newcomb_z = (c - df_light['Speed [km/s]'].mean())/df_light['Speed [km/s]'].std()
newcomb_rel = (df_light['Speed [km/s]'].mean() - c)/c*100

# %%
#// END_TODO [EDA_14i]

c, newcomb_z, newcomb_rel
# Out:
# (299792.458, 0.2199299134140127, -0.009536564756681631)

# %% [markdown]
# # Feedback
#
# Please fill in this questionaire to help us improve this course for the next year. Your feedback will be anonymized and will not affect your grade in any way!

# %% [markdown]
# ### How many hours did you spend on these Exercises?
#
# Assign a number to `feedback_time`.

# %%
#// BEGIN_TODO [Feedback_1] (0 point)

10

#// END_TODO [Feedback_1] (0 point)

import numbers
assert isinstance(feedback_time, numbers.Number), "Please assign a number to feedback_time"
feedback_time

# %% [markdown]
# ### How difficult did you find these Exercises?
#
# Assign an integer to `feedback_difficulty`, on a scale 1 - 10, with 1 being very easy.

# %%
#// BEGIN_TODO [Feedback_2] (0 point)

3

#// END_TODO [Feedback_2] (0 point)

import numbers
assert isinstance(feedback_difficulty, numbers.Number), "Please assign a number to feedback_difficulty"
feedback_difficulty

# %% [markdown]
# ### (Optional) What did you like?
#
# Assign a string to `feedback_like`.

# %%
#// BEGIN_TODO [Feedback_3] (0 point)

'not much'

#// END_TODO [Feedback_3] (0 point)

# %% [markdown]
# ### (Optional) What can be improved?
#
# Assign a string to `feedback_improve`.

# %%
#// BEGIN_TODO [Feedback_4] (0 point)

'make a seperate manual and a separate notebook so things are easy to look up'

#// END_TODO [Feedback_4] (0 point)

# %% [markdown]
# ## How to submit your work
#
# 1. **Before submitting**, you must run your notebook by doing **Kernel > Restart & Run All**.
#    Make sure that your notebook runs without errors **in linear order**.
#
# 2. Remember to rename the notebook, replacing `...-template.ipynb` with `...-yourIDnr.ipynb`, where `yourIDnr` is your TU/e identification number.
#
# 3. Submit the executed notebook with your work
#    for the appropriate assignment in **Canvas**.
#
# * In the **Momotor** tab in Canvas,
#   you can select that assignment again to find some feedback on your submitted work.
#
# * If there are any problems reported by _Momotor_,
#   then you need to fix those,
#   and **resubmit the fixed notebook**.
#
# In case of a high workload on our server
# (because many students submit close to the deadline),
# it may take longer to receive the feedback.

# %% [markdown]
# ---

# %%
# List all defined names
# %whos
# Out:
# Variable                       Type                Data/Info
# ------------------------------------------------------------
# AUTHOR_DATE                    str                 2019-02-07
# AUTHOR_ID_NR                   str                 1349171
# AUTHOR_NAME                    str                 Kyra Moviat
# c                              float               299792.458
# capital_Kingston               Series              0      False\n1      Fals<...> Length: 251, dtype: bool
# cleam_speed_is_normal          bool                True
# clean_speed_is_normal          bool                True
# countries_in_EU                Series              0       True\n1      Fals<...> Length: 251, dtype: bool
# countries_in_EU_not_RUS        Series              0       True\n1      Fals<...>nLength: 251, dtype: bool
# country_data                   DataFrame                                    <...>n\n[251 rows x 9 columns]
# country_data_row               DataFrame                index               <...>n\n[251 rows x 8 columns]
# country_data_sorted_by_area    DataFrame                index               <...>\n[251 rows x 10 columns]
# country_data_sorted_by_pop     DataFrame                index               <...>n\n[251 rows x 8 columns]
# country_data_sortedbydensity   DataFrame                index               <...>\n[251 rows x 10 columns]
# df                             DataFrame              A      B      C\n0  1 <...>False\n3  4   four   True
# df_drop                        DataFrame              A      B\n0  1    one\<...>n2  3  three\n3  4   four
# df_light                       DataFrame               Value   Speed [km/s]\<...>\n\n[66 rows x 2 columns]
# df_light_clean                 DataFrame               Value   Speed [km/s]\<...>\n\n[61 rows x 2 columns]
# df_shopping_list               DataFrame                 Item  Price (Euro)\<...>n4  carrots           1.5
# df_short_list                  DataFrame                 Item  Price (Euro)\<...>n3  bananas           2.5
# df_shorter_list                DataFrame               Item  Price (Euro)\n0<...>0\n2  chips           2.7
# df_slice                       DataFrame              A      B      C\n1  8 <...> True\n2  3  three  False
# df_years                       DataFrame                Name  Year of birth\<...>n4  Simone           1962
# file_countries                 str                 ./datasets/country-data.csv
# file_light                     str                 ./datasets/light.csv
# grouped                        DataFrameGroupBy    <pandas.core.groupby.Data<...>ct at 0x000001C225802B70>
# items                          list                n=5
# large_population               Series              0      False\n1      Fals<...> Length: 251, dtype: bool
# names                          list                n=5
# newcomb_rel                    float               -0.009536564756681631
# newcomb_z                      float               0.2199299134140127
# nietrusland                    Series              0      True\n1      True\<...> Length: 251, dtype: bool
# np                             module              <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# original_speed_is_normal       bool                True
# out                            Series              0     False\n1     False\<...>, Length: 66, dtype: bool
# pd                             module              <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt                            module              <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# pop_less_20M                   Series              0       True\n1       Tru<...> Length: 251, dtype: bool
# pop_more_10M                   Series              0      False\n1      Fals<...> Length: 251, dtype: bool
# prices                         list                n=5
# rusland                        Series              0      False\n1      Fals<...> Length: 251, dtype: bool
# se_shopping_list               Series              bread      2.0\nmilk     <...>ce (Euro), dtype: float64
# se_years                       Series              Peter     1998\nAnna     <...>rs of birth, dtype: int64
# sns                            module              <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>
# stats_observation              str                 c
# tb                             Series              0     False\n1     False\<...>, Length: 66, dtype: bool
# ts                             Series              0     False\n1     False\<...>, Length: 66, dtype: bool
# x                              Series              0     24.828\n1     24.82<...>ength: 66, dtype: float64
# y                              Series              0     299742.226518\n1   <...>ength: 66, dtype: float64
# years                          list                n=5

# %% [markdown]
# ---
#
# # (End of Notebook)
#
# &copy; 2017-2019 - **TU/e** - Eindhoven University of Technology
